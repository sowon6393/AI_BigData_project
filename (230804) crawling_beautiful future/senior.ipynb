# %%
from urllib.request import urlopen
from bs4 import BeautifulSoup
from selenium import webdriver
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import re
from matplotlib import font_manager

fe = font_manager.FontEntry(
    fname=r'C:\Users\KDP-26-\AppData\Local\Microsoft\Windows\Fonts\TENADA.ttf', # ttf 파일이 저장되어 있는 경로
    name='TENADA')                        # 이 폰트의 원하는 이름 설정
font_manager.fontManager.ttflist.insert(0, fe)              # Matplotlib에 폰트 추가
plt.rcParams.update({'font.size': 12, 'font.family': 'TENADA'}) # 폰트 설정


argument1=[]#경력
argument2=[]
argument3=[]
argument4=[]
argument5=[]
argument6=[]
argument7=[]
argument8=[]
argument9=[]
argument10=[]
argument11=[]
argument12=[]
argument13=[]
argument14=[]
argument15=[]
argument16=[]
argument17=[]
argument18=[]
argument19=[]
argument20=[]
argument21=[]
argument22=[]
argument23=[]
argument24=[]
argument25=[]
argument26=[]

# %%
for i in range(1,22):

    html = urlopen(f"https://www.work.go.kr/empInfo/empInfoSrch/list/dtlEmpSrchList.do?careerTo=120&keywordJobCd=&occupation=132000%2C025%2C024%2C023&templateInfo=&shsyWorkSecd=&rot2WorkYn=&payGbn=&resultCnt=10&keywordJobCont=&cert=&cloDateStdt=&moreCon=&minPay=&codeDepth2Info=11000&isChkLocCall=&sortFieldInfo=DATE&major=&resrDutyExcYn=&eodwYn=&sortField=DATE&staArea=&sortOrderBy=DESC&keyword=&termSearchGbn=all&carrEssYns=&benefitSrchAndOr=O&disableEmpHopeGbn=&webIsOut=&actServExcYn=&maxPay=&keywordStaAreaNm=&emailApplyYn=&listCookieInfo=DTL&pageCode=&codeDepth1Info=11000&keywordEtcYn=&publDutyExcYn=&keywordJobCdSeqNo=&exJobsCd=&templateDepthNmInfo=&computerPreferential=&regDateStdt=&employGbn=&empTpGbcd=1&region=&infaYn=&resultCntInfo=10&siteClcd=WORK&cloDateEndt=&sortOrderByInfo=DESC&currntPageNo=1&indArea=&careerTypes=E&searchOn=Y&tlmgYn=&subEmpHopeYn=&academicGbn=&templateDepthNoInfo=&foriegn=&mealOfferClcd=&station=&moerButtonYn=Y&holidayGbn=&srcKeyword=&enterPriseGbn=all&academicGbnoEdu=noEdu&cloTermSearchGbn=all&keywordWantedTitle=&stationNm=&benefitGbn=&keywordFlag=&notSrcKeyword=&essCertChk=&isEmptyHeader=&depth2SelCode=&_csrf=59771df0-40da-4b72-b9b3-3991b3797301&keywordBusiNm=&preferentialGbn=&rot3WorkYn=&pfMatterPreferential=&regDateEndt=&staAreaLineInfo1=11000&staAreaLineInfo2=1&pageIndex={i}&termContractMmcnt=&careerFrom=36&laborHrShortYn=#viewSPL")
    soup = BeautifulSoup(html,features="lxml")
    
    a_list = soup.select("div.cp-info-in > a")

    for i in a_list:
    
        sites = "https://www.work.go.kr" + i["href"]
        # print(sites)
        html2 = urlopen(sites)
        soup2 = BeautifulSoup(html2,features="lxml")
        # list1= soup2.select_one("#contents > section > div > div.careers-area > div.careers-new > div.border > div.left")
        # career=list1.select_one("div:nth-child(2) > div:nth-child(1) > div > ul > li:nth-child(1) span").text.strip()
        # study =list1.select_one("div:nth-child(2) > div:nth-child(1) > div > ul > li:nth-child(2) > span").text.strip()
        list1 = soup2.select("#contents > section > div > div.careers-area > div.careers-new > div.border > div.left")
        for i in list1:
            argument1.append(i.select_one("div:nth-child(3) > div  div > ul > li span").text.strip().replace("\n","").replace("\t","").replace(" ",""))
            argument2.append(i.select_one("div:nth-child(2) > div:nth-child(1) > div > ul > li:nth-child(2) > span").text.strip().replace("\n","").replace("\t","").replace(" ",""))
            argument3.append(i.select_one("div:nth-child(2) > div:nth-child(2) > div > ul > li:nth-child(1) > span").text.strip().replace("\n","").replace("\t","").replace(" ",""))
            argument4.append(i.select_one("div:nth-child(2) > div:nth-child(2) > div > ul > li:nth-child(2) > span").text.strip().replace("\n","").replace("\t","").replace(" ",""))
            argument5.append(i.select_one("div:nth-child(3) > div:nth-child(1) > div > ul > li:nth-child(1) > span").text.strip().replace("\n","").replace("\t","").replace(" ",""))
            argument6.append(i.select_one("div:nth-child(3) > div:nth-child(1) > div > ul > li:nth-child(2) > span").text.strip().replace("\n","").replace("\t","").replace(" ",""))
            argument7.append(i.select_one("div:nth-child(3) > div:nth-child(2) > div > ul > li").text.strip().replace("\n","").replace("\t","").replace(" ",""))
        list2= soup2.select("#contents > section > div > div.careers-area > div.careers-new > div.border > div.right")
        for i in list2:
            argument8.append(i.select_one("div.info > ul > li:nth-child(1) > div").text.strip().replace("\n","").replace("\t","").replace(" ",""))
            argument9.append(i.select_one("div.info > ul > li:nth-child(2) > div").text.strip().replace("\n","").replace("\t","").replace(" ",""))
            argument10.append(i.select_one("div.info > ul > li:nth-child(3) > div").text.strip().replace("\n","").replace("\t","").replace(" ",""))
            argument11.append(i.select_one("div.info > ul > li:nth-child(4) > div").text.strip().replace("\n","").replace("\t","").replace(" ",""))
            argument12.append(i.select_one("div.info > ul > li:nth-child(5) > div").text.strip().replace("\n","").replace("\t","").replace(" ",""))
            argument13.append(i.select_one("div.info > ul > li:nth-child(6) > div").text.strip().replace("\n","").replace("\t","").replace(" ",""))
            argument14.append(i.select_one("div.info > ul > li:nth-child(7) > div").text.strip().replace("\n","").replace("\t","").replace(" ",""))
        argument15.append(soup2.select_one("#contents > section > div > div.careers-area > div:nth-child(4) > table > tbody > tr > td").text.strip().replace("\n","").replace("\t","").replace(" ",""))
        argument16.append(soup2.select_one("div.careers-area > div:nth-child(6) > table tr > td:nth-child(1)").text.strip().replace("\n","").replace("\t","").replace(" ",""))
        argument17.append(soup2.select_one("#contents > section > div > div.careers-area > div:nth-child(6) > table > tbody > tr > td:nth-child(3)").text.strip().replace("\n","").replace("\t","").replace(" ",""))
        argument18.append(soup2.select_one("#contents > section > div > div.careers-area > div:nth-child(14) > table > tbody > tr > td:nth-child(1)").text.strip().replace("\n","").replace("\t","").replace(" ",""))
        argument19.append(soup2.select_one("#contents > section > div > div.careers-area > div:nth-child(14) > table > tbody > tr > td:nth-child(2)").text.strip().replace("\n","").replace("\t","").replace(" ",""))
        argument20.append(soup2.select_one("#contents > section > div > div.careers-area > div:nth-child(14) > table > tbody > tr > td:nth-child(3)").text.strip().replace("\n","").replace("\t","").replace(" ",""))
        argument21.append(soup2.select_one("#contents > section > div > div.careers-area > div:nth-child(14) > table > tbody > tr > td:nth-child(4)").text.strip().replace("\n","").replace("\t","").replace(" ",""))
        argument22.append(soup2.select_one("#contents > section > div > div.careers-area > div:nth-child(14) > table > tbody > tr > td:nth-child(5)").text.strip().replace("\n","").replace("\t","").replace(" ",""))
        argument23.append(soup2.select_one("#contents > section > div > div.careers-area > div.careers-table.cnts.v1.mt20 > table > tbody > tr:nth-child(2) td:nth-child(1)").text.strip().replace("\n","").replace("\t","").replace(" ",""))
        argument24.append(soup2.select_one("#contents > section > div > div.careers-area > div.careers-table.cnts.v1.mt20 > table > tbody > tr:nth-child(2) td:nth-child(2)").text.strip().replace("\n","").replace("\t","").replace(" ",""))
        argument25.append(soup2.select_one("#contents > section > div > div.careers-area > div.careers-table.cnts.v1.mt20 > table > tbody > tr:nth-child(4) td:nth-child(1)").text.strip().replace("\n","").replace("\t","").replace(" ",""))
        argument26.append(soup2.select_one("#contents > section > div > div.careers-area > div.careers-table.cnts.v1.mt20 > table > tbody > tr:nth-child(4) td:nth-child(2)").text.strip().replace("\n","").replace("\t","").replace(" ",""))
        soup.select


total_list = [argument1,argument2,argument3,argument4,argument5,argument6,argument7,argument8,argument9,argument10,argument11,argument12,argument13,argument14,argument15,argument16,argument17,argument18,argument19,argument20,argument21,argument22,argument23,argument24,argument25,argument26]

df = pd.DataFrame(total_list,index=['경력','학력','지역','임금','고용형태',
        '근무형태','복리후생','기업명','업종','기업규모',
        '설립년도','연매출액','홈페이지','근로자수','직무내용',
        '모집직종','관련직종','전공','자격면허','외국어능력',
        '병역대체 복무자채용','고용허가제','우대조건','컴퓨터 활용능력','기타우대사항',
        '작업환경'])

df=df.T

# %%
df.shape
# Out:
# (207, 26)

# %%
df["경력"].value_counts()
# Out:
# 경력(최소3년0개월이상)필수     65
# 경력(최소3년0개월이상)우대     60
# 경력(최소5년0개월이상)필수     29
# 경력(최소5년0개월이상)우대     24
# 경력(최소10년0개월이상)우대     6
# 경력(최소8년0개월이상)필수      4
# 경력(최소10년0개월이상)필수     4
# 경력(최소4년0개월이상)필수      4
# 경력(최소3년5개월이상)필수      1
# 경력(최소5년6개월이상)필수      1
# 경력(최소7년0개월이상)필수      1
# 경력(최소6년0개월이상)우대      1
# 경력(최소7년0개월이상)우대      1
# 경력(최소8년0개월이상)우대      1
# 경력(최소4년0개월이상)우대      1
# 경력(최소5년10개월이상)필수     1
# 경력(최소3년7개월이상)우대      1
# 경력(최소5년1개월이상)우대      1
# 경력(최소3년1개월이상)필수      1
# Name: 경력, dtype: int64

# %%
df["학력"].value_counts()
# Out:
# 학력무관               95
# 대졸(2~3년)~대졸(4년)    35
# 대졸(4년)~박사          23
# 대졸(2~3년)~박사        17
# 대졸(2~3년)~석사        11
# 대졸(4년)              7
# 대졸(4년)~석사           5
# 고졸~대졸(4년)           4
# 대졸(2~3년)            3
# 고졸~박사               3
# 박사                  1
# 고졸~석사               1
# 고졸                  1
# 고졸~대졸(2~3년)         1
# Name: 학력, dtype: int64

# %%
# 학력무관이면 그냥 출력, 다른 경우는 학력 최저기준을 기준으로 출력

def edu_slice(str1):
    if str1!="학력무관":
        return str1[:2]+"이상"
    else:
        return str1
# 학력 재분류
df["학력"]=df["학력"].apply(edu_slice)

# %%
df["학력"].value_counts()
# Out:
# 대졸이상    101
# 학력무관     95
# 고졸이상     10
# 박사이상      1
# Name: 학력, dtype: int64

# %%
# 지역은 너무 세부적으로 있으니 도별로 구분
df["지역"]
# Out:
# 0                   서울특별시마포구백범로35,서강대학교동문회관1101호(신수동)
# 1                    경기도수원시권선구산업로156번길66,나동에스퓨얼셀(고색동)
# 2                        경상남도창원시성산구완암로50,넥스동712호(성산동)
# 3                                경상북도구미시산동읍첨단기업1로82-3
# 4                     경기도광명시하안로60,광명SK테크노파크C-705(소하동)
#                             ...
# 202                        서울특별시성동구성수일로55,SK테크노빌딩403호
# 203                               경기도화성시동탄산단2길58(방교동)
# 204    경기도안양시만안구덕천로152번길25,안양아이에스BIZ타워센트럴A동2102호2101호
# 205                   서울특별시서초구강남대로53길8,스타크강남빌딩8층(서초동)
# 206                          인천광역시계양구서운산단로2길73,-(서운동)
# Name: 지역, Length: 207, dtype: object

# %%
df["지역"]=df["지역"].str.replace("도","도 ").str.replace("시","시 ").str.split(" ").str[0]

# %%
df["지역"].value_counts()
# Out:
# 서울특별시      62
# 경기도        61
# 경상남도       13
# 경상북도       11
# 대구광역시      11
# 부산광역시       9
# 인천광역시       8
# 대전광역시       7
# 전라남도        6
# 전라북도        6
# 충청남도        4
# 강원특별자치도     4
# 광주광역시       2
# 충청북도        2
# 제주특별자치도     1
# Name: 지역, dtype: int64

# %%
df["임금"].str.replace("연봉","").str.replace("월급","").str.replace("시급","").str.replace("만원","").str.replace("이상","").str.replace(",","").str.split("~")
# Out:
# 0             [300]
# 1      [4000, 7000]
# 2            [4000]
# 3             [450]
# 4      [5000, 7000]
#            ...
# 202          [4000]
# 203          [6000]
# 204          [5000]
# 205      [400, 800]
# 206    [4500, 4500]
# Name: 임금, Length: 207, dtype: object

# %%
# 임금 부분을 숫자로 변경 및 평균으로 변경하는 함수
def wage_avg(list1):
    
    if int(list1[0])>9000:
        if len(list1)==1:
            return int(list1[0])*40*52/10000
        else:
            wage =int((int(list1[0])+int(list1[1]))/2)*40*52/10000
            return wage
    
    elif int(list1[0])>1000:
        if len(list1)==1:
            return int(list1[0])
        else:
            wage =int((int(list1[0])+int(list1[1]))/2)
            return wage
    elif int(list1[0])<1000:
        if len(list1)==1:
            return int(list1[0])*12
        else:
            wage =int((int(list1[0])+int(list1[1]))/2)*12
            return wage

# %%
# 수치형 데이터로 변경
df["임금"]=df["임금"].str.replace("연봉","").str.replace("월급","").str.replace("만원","").str.replace("원","").str.replace("시급","").str.replace("이상","").str.replace(",","").str.split("~").apply(wage_avg)

# %%
df["임금"]=df["임금"].apply(lambda x: int(x))

# %%
df["임금"]
# Out:
# 0      3600
# 1      5500
# 2      4000
# 3      5400
# 4      6000
#        ...
# 202    4000
# 203    6000
# 204    5000
# 205    7200
# 206    4500
# Name: 임금, Length: 207, dtype: int64

# %%
# 고용형태는 기간 유무로만 구분 필요
df["고용형태"].value_counts()
# Out:
# 기간의정함이없는근로계약             183
# 기간의정함이있는근로계약              21
# 기간의정함이있는근로계약(시간(선택)제)      2
# 기간의정함이없는근로계약(시간(선택)제)      1
# Name: 고용형태, dtype: int64

# %%
df["고용형태"]=df["고용형태"].str.replace("\(시간\(선택\)제\)","")
# Out:
# C:\Users\KDP-024\AppData\Local\Temp\ipykernel_1160\3589070156.py:1: FutureWarning: The default value of regex will change from True to False in a future version.
#   df["고용형태"]=df["고용형태"].str.replace("\(시간\(선택\)제\)","")

# %%
df["고용형태"].value_counts()
# Out:
# 기간의정함이없는근로계약    184
# 기간의정함이있는근로계약     23
# Name: 고용형태, dtype: int64

# %%
# 근무형태는 변경필요 X
df["근무형태"].value_counts()
# Out:
# 주5일근무    205
# 주6일근무      1
# 주3일근무      1
# Name: 근무형태, dtype: int64

# %%
# 형태소 분석해야 하나..? 생각
df['복리후생']
# Out:
# 0
# 1        식사제공(중식비지급)
# 2
# 3      기숙사제공식사제공(1식)
# 4             통근버스제공
#            ...
# 202      식사제공(중식비지급)
# 203         식사제공(2식)
# 204      식사제공(중식비지급)
# 205            교육비제공
# 206         식사제공(1식)
# Name: 복리후생, Length: 207, dtype: object

# %%
# 기업명에 있던 "(주)" 및 "주식회사" 제거

df["기업명"]=df["기업명"].str.replace("주식회사","").str.replace("\(주\)","")
# Out:
# C:\Users\KDP-024\AppData\Local\Temp\ipykernel_1160\2541823816.py:3: FutureWarning: The default value of regex will change from True to False in a future version.
#   df["기업명"]=df["기업명"].str.replace("주식회사","").str.replace("\(주\)","")

# %%
df["기업명"].value_counts()
# Out:
# 수퍼빈           4
# 우리요           2
# 영진직업전문학교      2
# 더크림유니언        2
# 첫눈            2
#              ..
# 메디라인액티브코리아    1
# 텍스타일디자인뱅크     1
# 우솔데이타         1
# 가람이노션         1
# 이노디스          1
# Name: 기업명, Length: 190, dtype: int64

# %%
# 이거는 좀 고민해야할거 같음.
df["업종"].value_counts()
# Out:
# 컴퓨터프로그래밍서비스업           26
# 응용소프트웨어개발및공급업          20
# 컴퓨터시스템통합자문및구축서비스업      18
# 시스템소프트웨어개발및공급업         12
# 기타정보기술및컴퓨터운영관련서비스업      8
#                        ..
# 사업시설유지ㆍ관리서비스업           1
# 전기회로개폐,보호장치제조업          1
# 경비및경호서비스업               1
# 통신ㆍ방송장비및부품도매업           1
# 기타기계ㆍ장비조립용플라스틱제품제조업     1
# Name: 업종, Length: 80, dtype: int64

# %%
#대부분 중소기업이긴 한데, 이건 빈 공백 어떻게 할지생각
df["기업규모"].value_counts()
# Out:
# 중소기업    179
#          26
# 기타        2
# Name: 기업규모, dtype: int64

# %%
# 설립년도 없는 곳 그냥 0으로 처리함
# 0으로 처리해야 나중에 불린 인덱스 조건 줘서 하기 좋을거 같아서
# ~년도 없앰
# int 형으로 바꿈
df["설립년도"]=df["설립년도"].str[:4].replace("",0).apply(lambda x :int(x))

# %%
df["설립년도"].value_counts()
# Out:
# 0       44
# 2021    16
# 2015    15
# 2019    14
# 2018    11
# 2017    10
# 2011    10
# 2013     9
# 2020     8
# 2004     8
# 2022     7
# 2010     7
# 2001     5
# 2009     5
# 2016     5
# 2008     4
# 2012     4
# 2014     4
# 2005     4
# 2000     3
# 1993     2
# 2006     2
# 1997     1
# 1989     1
# 1998     1
# 1980     1
# 2023     1
# 2003     1
# 1969     1
# 2002     1
# 2007     1
# 1991     1
# Name: 설립년도, dtype: int64

# %%
df["연매출액"].str.replace(",","").str.replace("백만원","").value_counts()
# Out:
#          90
# 2000      6
# 10000     6
# 1500      5
# 3000      5
#          ..
# 31492     1
# 920       1
# 2730      1
# 2144      1
# 19531     1
# Name: 연매출액, Length: 76, dtype: int64

# %%
#쓰지 못하는 데이터 변겅
df["홈페이지"]
# Out:
# 0                        -
# 1      www.s-fuelcell.com/
# 2            smart-s.co.kr
# 3             vnseng.co.kr
# 4       www.witconintl.com
#               ...
# 202        www.cellbig.com
# 203                      -
# 204                      -
# 205     www.jmkbuddies.com
# 206                      -
# Name: 홈페이지, Length: 207, dtype: object

# %%
# 근로자수 수치형으로 변경
df["근로자수"]=df["근로자수"].str.replace("명","").apply(lambda x: int(x))

# %%
# 이게 진짜 단어로 쪼개야 할듯 -> 형태소로
df["직무내용"].str.contains("SQL").sum()
# Out:
# 23

# %%
df["직무내용"]
# Out:
# 0      지원자격\rㆍ경력 : 경력 5년 ~ 10년(과장, 차장, 팀장급)\rㆍ기타 필수 사...
# 1      * 수소 연료전지 시스템 최적화, 평가 및 시험 분석\r* 연료전지시스템 개발 관련...
# 2                     웹 개발 인원 모집합니다.\r경력5년 이상 경력자 모집합니다.
# 3      자동화 장비 미쓰비씨  PLC 프로그래머\r- LCD, FA 자동화장비 제어 경력자...
# 4      [주요업무]\r. 카메라 영상 후 처리 및 신호 처리 S/W개발\r. PAN/TIL...
#                              ...
# 202    (회사소개)\r㈜셀빅은 2004년에 설립된 회사로 자본금 7억원, 매출액 102억,...
# 203    [산업용전자기기소프트웨어개발]\r- 시스템 소프트웨어 설계\r- 소프트웨어구조 설계...
# 204                          Emebedded system , Firmware
# 205    1. 업무내용\r   - 정보시스템 구축사업 DBA\r   - 정보시스템 DB 설계...
# 206    ■ 직무내용 : 전산업무 전반(전산프로그램 전반)/네트워크 관리 \r■ 경력 3년 ...
# Name: 직무내용, Length: 207, dtype: object

# %%
#세부사항을 쪼갤지 말지 물어보기

df["모집직종"].value_counts()
# Out:
# 웹개발자(웹엔지니어·웹프로그래머)                        32
# 응용소프트웨어개발자                                19
# C언어및그외프로그래밍언어전문가                          17
# 시스템소프트웨어개발자                               11
# 웹개발자                                      11
# JAVA프로그래밍언어전문가                             9
# 펌웨어및임베디드소프트웨어프로그래머                         9
# 데이터설계및프로그래머                                8
# 웹기획자                                       8
# IT기술지원전문가                                  8
# 시스템소프트웨어개발자(프로그래머)                         7
# 모바일애플리케이션프로그래머(앱·어플개발)                     6
# 컴퓨터시스템설계및분석가                               6
# 범용응용소프트웨어프로그래머(ERP,정보처리,재무관리등)             5
# 게임프로그래머                                    3
# 데이터베이스운영·관리자                               3
# 정보시스템운영자                                   3
# 산업특화응용소프트웨어프로그래머(국방,항공,교통,에너지,금융,자동차등)     3
# 네트워크관리자(클라우딩컴퓨터운영관리자)                      3
# 웹운영자(홈페이지관리자)                              3
# IT컨설턴트                                     3
# UX/UI디자이너                                  2
# 데이터전문가                                     2
# 컴퓨터시스템전문가                                  2
# IT테스터및ITQA전문가                              2
# 기계·금속제도사(캐드원)                              2
# 통신장비설치·수리원                                 1
# 금속기계부품조립원                                  1
# 기타정보통신기기설치·수리원                             1
# 통신기기·장비개발자및연구원                             1
# 전자공학기술자및연구원                                1
# 생산·품질사무원                                   1
# 정보통신관리자(부서장)                               1
# 전기기기·제품개발기술자및연구원                           1
# 머천다이저(MD)                                  1
# IT기술영업원(전산장비,소프트웨어)                        1
# 컴퓨터하드웨어기술자및연구원                             1
# 웹디자이너                                      1
# 플라스틱금형제조원                                  1
# 전기계측제어기술자(전기패널,계장,공정자동화전기등)                1
# 정보보안전문가                                    1
# 총무및일반사무원                                   1
# 네트워크시스템개발자                                 1
# 경영기획사무원                                    1
# 산업용전자제품개발기술자및연구원                           1
# 온라인판매원                                     1
# Name: 모집직종, dtype: int64

# %%
# 빈데이터가 많음
df["관련직종"].value_counts()
# Out:
#                                                      90
# JAVA프로그래밍언어전문가                                        9
# C언어및그외프로그래밍언어전문가                                      5
# 데이터설계및프로그래머                                           5
# 웹기획자                                                  5
#                                                      ..
# 범용응용소프트웨어프로그래머(ERP,정보처리,재무관리등),웹개발자(웹엔지니어·웹프로그래머)     1
# 웹개발자(웹엔지니어·웹프로그래머),모바일애플리케이션프로그래머(앱·어플개발)             1
# 데이터분석가(빅데이터분석가)                                       1
# 컴퓨터하드웨어기술자및연구원                                        1
# 웹운영자(홈페이지관리자)                                         1
# Name: 관련직종, Length: 82, dtype: int64

# %%
# 안쓰는 데이터
df["전공"].value_counts()
# Out:
#                                                       131
# 전산학·컴퓨터공학(학과:정보통신공학부컴퓨터공학전공)                            2
# 전산학·컴퓨터공학(학과:전산학과)                                      2
# 응용소프트웨어공학(학과:컴퓨터ㆍ소프트웨어공학부)응용소프트웨어공학(학과:소프트웨어개발전공)       2
# 전산학·컴퓨터공학(학과:컴퓨터과학과)응용소프트웨어공학(학과:소프트웨어학과)               2
#                                                      ...
# 전자공학(학과:전자공학전공)                                         1
# 전산학·컴퓨터공학(학과:컴퓨터공학계열)응용소프트웨어공학(학과:컴퓨터소프트웨어ㆍ정보통신전공)      1
# 전산학·컴퓨터공학(학과:공과대학컴퓨터공학과)응용소프트웨어공학(학과:응용소프트웨어과학전공)       1
# 응용소프트웨어공학(학과:멀티미디어소프트웨어공학전공)공학교육(학과:컴퓨터교육과)             1
# 전산학·컴퓨터공학(학과:컴퓨터공학계열)응용소프트웨어공학(학과:게임&멀티미디어공학전공)         1
# Name: 전공, Length: 72, dtype: int64

# %%
# df["자격면허"].str.contains("데이터").sum()
df["자격면허"]
# Out:
# 0      정보처리기능사(우대),리눅스마스터(우대)
# 1                        관계없음
# 2                        관계없음
# 3                        관계없음
# 4                        관계없음
#                 ...
# 202                      관계없음
# 203                      관계없음
# 204              기타:전공관련자격자우대
# 205                      관계없음
# 206                      관계없음
# Name: 자격면허, Length: 207, dtype: object

# %%
# 데이터 자체를 못씀

df["외국어능력"].value_counts()
# Out:
#                 186
# 영어(중)            11
# 영어(상)             3
# 영어(중),일어(중)       1
# 영어(중),중국어(하)      1
# 영어(중),중국어(중)      1
# 중국어(중),영어(중)      1
# 영어(하)             1
# 타이어(상)            1
# 일어(하)             1
# Name: 외국어능력, dtype: int64

# %%
# 의미없는 데이터
df["병역대체 복무자채용"].value_counts()
# Out:
# 비희망                  205
# 희망(보충역대상자/산업기능요원)      2
# Name: 병역대체 복무자채용, dtype: int64

# %%
# 의미없는 데이터
df["고용허가제"].value_counts()
# Out:
#                              206
# 내국인구인노력기간이후고용허가제대상외국인채용예정      1
# Name: 고용허가제, dtype: int64

# %%
df["우대조건"].value_counts()
# Out:
#                                                  161
# 차량소지자,운전면허증                                       19
# 운전면허증                                             10
# 고용촉진장려금대상자                                         4
# 장애인,보훈취업지원대상자                                      2
# 고용촉진장려금대상자,차량소지자,운전면허증                             2
# 차량소지자                                              2
# 고용촉진장려금대상자,운전면허증                                   2
# (준)고령자(50세이상),차량소지자,운전면허증                          1
# (준)고령자(50세이상),장기복무제대군인,고용촉진장려금대상자,차량소지자,운전면허증      1
# 장애인,북한이탈주민,고용촉진장려금대상자,보훈취업지원대상자                    1
# 보훈취업지원대상자                                          1
# 고용촉진장려금대상자,보훈취업지원대상자                               1
# Name: 우대조건, dtype: int64

# %%
df["컴퓨터 활용능력"].value_counts()
# Out:
#                                                                                                    139
# 문서작성 (워드프로세스 활용),표계산 (스프레드시트 활용)  ,프레젠테이션 프로그램 활용                                                   31
# 문서작성 (워드프로세스 활용),프레젠테이션 프로그램 활용                                                                     10
# 문서작성 (워드프로세스 활용)                                                                                     7
# 문서작성 (워드프로세스 활용),표계산 (스프레드시트 활용)                                                                     6
# 표계산 (스프레드시트 활용)  ,프레젠테이션 프로그램 활용                                                                     2
# 기타(컴퓨터활용능력 우수자)                                                                                      2
# 프레젠테이션 프로그램 활용                                                                                       1
# 문서작성 (워드프로세스 활용),프레젠테이션 프로그램 활용,기타 (서버관리 기초, 네트워크 기초 , DBMS 기초, 소프트웨어 관리 기본,  문서작성)                  1
# 문서작성 (워드프로세스 활용),표계산 (스프레드시트 활용)  ,프레젠테이션 프로그램 활용,기타 (Figma, GitHub, Sketch, UI, UX, Wireframe)      1
# 표계산 (스프레드시트 활용)                                                                                      1
# 기타(웹프로그램 가능자)                                                                                        1
# 문서작성 (워드프로세스 활용),기타 (프로그래밍)                                                                          1
# 문서작성 (워드프로세스 활용),표계산 (스프레드시트 활용)  ,프레젠테이션 프로그램 활용,회계프로그램,기타 (ERP 경험자우대)                              1
# 문서작성 (워드프로세스 활용),표계산 (스프레드시트 활용)  ,프레젠테이션 프로그램 활용,회계프로그램                                             1
# 기타(Figma 활용)                                                                                         1
# 문서작성 (워드프로세스 활용),표계산 (스프레드시트 활용)  ,프레젠테이션 프로그램 활용,기타 (MS 오피스 등 활용 가능자)                               1
# Name: 컴퓨터 활용능력, dtype: int64

# %%
df["기타우대사항"].str.contains("").sum()
# Out:
# 207

# %%
# 의미 없는 데이타
df["작업환경"].value_counts()
# Out:
#                                                                                                    196
# 작업장소:실내                                                                                              5
# 작업장소:실내드는힘:5Kg이내의물건을다룸서거나걷기:서거나걷는일거의없음듣고말하기:간단한듣고말하기필요시력:아주작은글씨를읽을수있는정도손작업:정밀한작업양손사용:한손으로보조하는작업      2
# 작업장소:실내드는힘:5Kg이내의물건을다룸서거나걷기:서거나걷는일거의없음듣고말하기:간단한듣고말하기필요시력:일상적인활동이가능한정도양손사용:양손으로작업                     2
# 작업장소:실내드는힘:5Kg이내의물건을다룸서거나걷기:서거나걷는일거의없음듣고말하기:듣고말하기중요시력:일상적인활동이가능한정도양손사용:양손으로작업                        1
# 작업장소:실내드는힘:5Kg이내의물건을다룸서거나걷기:서거나걷는일거의없음듣고말하기:듣고말하기중요시력:일상적인활동이가능한정도                                   1
# Name: 작업환경, dtype: int64

# %%
df["경력"]=df["경력"].str.replace("경력","").str.replace("\(최소","").str.replace("\)","").str.replace("이상","").str.replace("우대","").str.replace("필수","").str.replace("0개월","").str.replace("개월","").str.replace("년",".").apply(lambda x: float(x))
# Out:
# C:\Users\KDP-024\AppData\Local\Temp\ipykernel_1160\3985731847.py:1: FutureWarning: The default value of regex will change from True to False in a future version.
#   df["경력"]=df["경력"].str.replace("경력","").str.replace("\(최소","").str.replace("\)","").str.replace("이상","").str.replace("우대","").str.replace("필수","").str.replace("0개월","").str.replace("개월","").str.replace("년",".").apply(lambda x: float(x))

# %%
df["경력"]
# Out:
# 0       5.0
# 1       3.0
# 2       5.0
# 3       5.0
# 4       5.0
#        ...
# 202     8.0
# 203     5.0
# 204    10.0
# 205     5.0
# 206     3.0
# Name: 경력, Length: 207, dtype: float64

# %%
df = df.assign(sqlp=df['자격면허'].apply(lambda x: 'SQLP(SQL전문가)' in x))
df = df.assign(a=df['자격면허'].apply(lambda x: '정보처리기사' in x))
df = df.assign(b=df['자격면허'].apply(lambda x: '정보통신기사' in x))
df = df.assign(c=df['자격면허'].apply(lambda x: '전기' in x))#
df = df.assign(d=df['자격면허'].apply(lambda x: '리눅스' in x))
df = df.assign(e=df['직무내용'].str.lower().apply(lambda x: 'c' in x))
df = df.assign(f=df['직무내용'].str.lower().apply(lambda x: 'java' in (' ' + x + ' ')))
df = df.assign(g=df['직무내용'].str.lower().apply(lambda x: 'javascript' in (' ' + x + ' ')))
df = df.assign(h=df['직무내용'].str.lower().apply(lambda x: 'html' in (' ' + x + ' ')))
df = df.assign(i=df['직무내용'].str.lower().apply(lambda x: 'python' in (' ' + x + ' ') or '파이썬' in (' ' + x + ' ')))

# %%
for i in range(df.shape[0]):
    if 'SQLP(SQL전문가)' in  df.loc[i,"자격면허"]:
        df.loc[i,"면허종류"] = 'SQLP(SQL전문가)'
    elif '정보처리기사' in  df.loc[i,"자격면허"]:
        df.loc[i,"면허종류"] = '정보처리기사'
    elif '정보통신기사' in  df.loc[i,"자격면허"]:
        df.loc[i,"면허종류"] = '정보통신기사'
    elif '전기' in  df.loc[i,"자격면허"]:
        df.loc[i,"면허종류"] = '전기기사'
    else:
        df.loc[i,"면허종류"] = False

# %%
fig= plt.figure(figsize=(20,7))
ax1 = fig.add_subplot(1,3,1)
ax2 = fig.add_subplot(1,3,2)
ax3 = fig.add_subplot(1,3,3)
contrast_colors = sns.color_palette("Dark2")
sns.barplot(x=["정보처리기사 자격증 O","정보처리기사 자격증 X"], y= [df.loc[df["a"],"임금"].mean(),df.loc[~df["a"],"임금"].mean()],palette=contrast_colors,ax=ax1,edgecolor="black")
ax1.set_title("정보처리기사 자격증에 따른 연봉",size=20)
ax1.set_xlabel("정보처리기사 자격증 유무",size=12)
ax1.set_ylabel("연봉(만원/년)",size=12)
for i in ax1.containers:
    ax1.bar_label(i,size=12)
ax1.bar_label


sns.barplot(x=["정보통신기사 자격증 O","정보통신기사 자격증 X"], y= [df.loc[df["b"],"임금"].mean(),df.loc[~df["b"],"임금"].mean()],palette=contrast_colors,ax=ax2,edgecolor="black")
ax2.set_title("정보통신기사 자격증에 따른 연봉",size=20)
ax2.set_xlabel("정보통신기사 자격증 유무",size=12)
ax2.set_ylabel("연봉(만원/년)",size=12)
for i in ax2.containers:
    ax2.bar_label(i,size=12)
ax2.bar_label

sns.barplot(x=["전기기사 자격증 O","전기기사 자격증 X"], y= [df.loc[df["c"],"임금"].mean(),df.loc[~df["c"],"임금"].mean()],palette=contrast_colors,ax=ax3,edgecolor="black")
ax3.set_title("전기기사 자격증에 따른 연봉",size=20)
ax3.set_xlabel("전기기사 자격증 유무",size=12)
ax3.set_ylabel("연봉(만원/년)",size=12)
for i in ax3.containers:
    ax3.bar_label(i,size=12)
ax3.bar_label

plt.show()

# %%
fig= plt.figure(figsize=(20,7))
ax1 = fig.add_subplot(1,3,1)
ax2 = fig.add_subplot(1,3,2)
ax3 = fig.add_subplot(1,3,3)
contrast_colors = sns.color_palette("Dark2")
sns.barplot(x=["리눅스 언어 O","리눅스 언어 X"], y= [df.loc[df["d"],"임금"].mean(),df.loc[~df["d"],"임금"].mean()],palette=contrast_colors,ax=ax1,edgecolor="black")
ax1.set_title("리눅스 언어에 따른 연봉",size=20)
ax1.set_xlabel("리눅스 언어 사용 여부",size=12)
ax1.set_ylabel("연봉(만원/년)",size=12)
for i in ax1.containers:
    ax1.bar_label(i,size=12)
ax1.bar_label

sns.barplot(x=["C 언어 O","C 언어 X"], y= [df.loc[df["e"],"임금"].mean(),df.loc[~df["e"],"임금"].mean()],palette=contrast_colors,ax=ax2,edgecolor="black")
ax2.set_title("C 언어에 따른 연봉",size=20)
ax2.set_xlabel("C 언어 사용 여부",size=12)
ax2.set_ylabel("연봉(만원/년)",size=12)
for i in ax2.containers:
    ax2.bar_label(i,size=12)
ax2.bar_label

sns.barplot(x=["JAVA 언어 O","JAVA 언어 X"], y= [df.loc[df["f"],"임금"].mean(),df.loc[~df["f"],"임금"].mean()],palette=contrast_colors,ax=ax3,edgecolor="black")
ax3.set_title("JAVA 언어에 따른 연봉",size=20)
ax3.set_xlabel("JAVA 언어 사용 여부",size=12)
ax3.set_ylabel("연봉(만원/년)",size=12)
for i in ax3.containers:
    ax3.bar_label(i,size=12)
ax3.bar_label

plt.show()

# %%
fig= plt.figure(figsize=(20,7))
ax1 = fig.add_subplot(1,3,1)
ax2 = fig.add_subplot(1,3,2)
ax3 = fig.add_subplot(1,3,3)
contrast_colors = sns.color_palette("Dark2")
sns.barplot(x=["JAVASCRIPT 언어 O","JAVASCRIPT 언어 X"], y= [df.loc[df["g"],"임금"].mean(),df.loc[~df["g"],"임금"].mean()],palette=contrast_colors,ax=ax1,edgecolor="black")
ax1.set_title("JAVASCRIPT 언어에 따른 연봉",size=20)
ax1.set_xlabel("JAVASCRIPT 언어 사용 여부",size=12)
ax1.set_ylabel("연봉(만원/년)",size=12)
for i in ax1.containers:
    ax1.bar_label(i,size=12)
ax1.bar_label

sns.barplot(x=["HTML 언어 O","HTML 언어 X"], y= [df.loc[df["h"],"임금"].mean(),df.loc[~df["h"],"임금"].mean()],palette=contrast_colors,ax=ax2,edgecolor="black")
ax2.set_title("HTML 언어에 따른 연봉",size=20)
ax2.set_xlabel("HTML 언어 사용 여부",size=12)
ax2.set_ylabel("연봉(만원/년)",size=12)
for i in ax2.containers:
    ax2.bar_label(i,size=12)
ax2.bar_label

sns.barplot(x=["PYTHON 언어 O","PYTHON 언어 X"], y= [df.loc[df["i"],"임금"].mean(),df.loc[~df["i"],"임금"].mean()],palette=contrast_colors,ax=ax3,edgecolor="black")
ax3.set_title("PYTHON 언어에 따른 연봉",size=20)
ax3.set_xlabel("PYTHON 언어 사용 여부",size=12)
ax3.set_ylabel("연봉(만원/년)",size=12)
for i in ax3.containers:
    ax3.bar_label(i,size=12)
ax3.bar_label

plt.show()

# %%
fig= plt.figure(figsize=(10,7))
ax1 = fig.add_subplot(1,1,1)

yoil_colors = sns.color_palette("RdPu", 4)

sns.barplot(x=df["학력"],y=df["임금"],data=df,ax=ax1,edgecolor="black",ci=None,palette=yoil_colors)
ax1.set_title("학력별 연봉",size=20)
ax1.set_xlabel("학력",size=12)
ax1.set_ylabel("연봉(만원/년)",size=12)
for i in ax1.containers:
    ax1.bar_label(i,size=12)

plt.show()
# Out:
# C:\Users\KDP-024\AppData\Local\Temp\ipykernel_1160\862369072.py:6: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.barplot(x=df["학력"],y=df["임금"],data=df,ax=ax1,edgecolor="black",ci=None,palette=yoil_colors)

# %%
fig= plt.figure(figsize=(14,7))
ax1 = fig.add_subplot(1,1,1)
hour_colors = sns.color_palette("RdBu", 15)


sns.barplot(x=df["지역"],y=df["임금"],data=df,ax=ax1,edgecolor="black",ci=None,palette=hour_colors)
ax1.set_title("지역별 연봉",size=20)
ax1.set_xlabel("지역",size=12)
ax1.set_ylabel("연봉(만원/년)",size=12)
plt.xticks(rotation=45)

for i in ax1.containers:
    ax1.bar_label(i,size=12)

plt.show()
# Out:
# C:\Users\KDP-024\AppData\Local\Temp\ipykernel_1160\2644846505.py:6: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.barplot(x=df["지역"],y=df["임금"],data=df,ax=ax1,edgecolor="black",ci=None,palette=hour_colors)

# %%
fig= plt.figure(figsize=(10,7))
ax1 = fig.add_subplot(1,1,1)

sns.barplot(x=df["고용형태"],y=df["임금"],data=df,ax=ax1,edgecolor="black",ci=None)
ax1.set_title("고용형태에 따른 연봉",size=20)
ax1.set_xlabel("고용형태",size=12)
ax1.set_ylabel("연봉(만원/년)",size=12)
for i in ax1.containers:
    ax1.bar_label(i,size=12)
plt.show()
# Out:
# C:\Users\KDP-024\AppData\Local\Temp\ipykernel_1160\1953307035.py:4: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.barplot(x=df["고용형태"],y=df["임금"],data=df,ax=ax1,edgecolor="black",ci=None)

# %%
fig= plt.figure(figsize=(15,7))
ax1 = fig.add_subplot(1,1,1)

sns.barplot(x="지역",y="임금",hue="학력",data=df,ax=ax1,edgecolor="black",ci=None)
ax1.set_title("학력별 지역별 연봉",size=20)
ax1.set_xlabel("지역",size=12)
ax1.set_ylabel("연봉(만원/년)",size=12)
plt.xticks(rotation=45)

plt.show()
# Out:
# C:\Users\KDP-024\AppData\Local\Temp\ipykernel_1160\3263999474.py:4: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.barplot(x="지역",y="임금",hue="학력",data=df,ax=ax1,edgecolor="black",ci=None)

# %%
list_work=" ".join(df["직무내용"].str.replace("\xa0","").str.replace("\r","").to_list())
import numpy as np
import PIL


icon = PIL.Image.open(r'D:\my_jupyter\EXAM_WEB_CRAWLING\project\electronic.png')
img = PIL.Image.new('RGB', icon.size, (255,255,255))
img.paste(icon, icon)
img = np.array(img)

from	wordcloud import	WordCloud
from	konlpy.tag import	Okt
from	collections	import	Counter
import	platform
okt =	Okt()	#	Open	Korean	Text	객체 생성
#	okt함수를 통해 읽어들인 내용의 형태소를 분석한다.
sentences_tag =	[]
sentences_tag =	okt.pos(list_work)

noun_adj_list =	[]
#	tag가 명사이거나 형용사인 단어들만 noun_adj_list에 넣어준다.
for	word,	tag	in	sentences_tag:
    if	tag	in	['Noun'	,	'Adjective']:
        noun_adj_list.append(word)
print(noun_adj_list)
#	가장 많이 나온 단어부터 40개를 저장한다.
counts	=	Counter(noun_adj_list)
tags	=	counts.most_common(40)
tags.pop(1)

if	platform.system()	==	'Windows':
    path	=	r'C:\Users\KDP-26-\AppData\Local\Microsoft\Windows\Fonts\TENADA.ttf'
wc =	WordCloud(font_path=path,	background_color="white",	max_font_size=150,mask=img, colormap='inferno')
cloud	=	wc.generate_from_frequencies(dict(tags))

plt.figure(figsize=(20,	10))
plt.axis('off')
plt.imshow(cloud)
plt.show()
# Out:
# ['지원', '자격', '경력', '경력', '과장', '차장', '팀', '급', '기타', '필수', '사항', '해당', '직무', '근무', '경험', '우수', '장기', '근무', '가능', '담당', '업무', '스마트', '오피스', '시스템', '개발', '사업', '부', '관리', '스마트', '오피스', '시스템', '백엔드', '개발', '및', '설계', '프론트엔드', '개발', '지원', '스킬', '우대', '사항', '웹', '앱', '개발', '경력', '를', '활용', '개발', '경험', '환경', '익숙하고', '등', '개발', '경험', '프론트엔드', '개발', '경험', '개발', '경험', '경험', '개발', '팀', '개발', '리더', '경험', '장기', '근무', '가능', '우수', '리더쉽', '소유자', '커뮤니케이션', '문제해결', '능력', '뛰어난', '분', '활발한', '성격', '가지', '친화력', '좋으', '신분', '복리', '후생', '성장', '위', '정기', '사내', '교육', '및', '세미나', '개최', '매년', '번의', '워크샵', '야유회', '주', '연월', '차제', '차제', '및', '휴가', '일수', '보장', '년', '조휴', '생일', '퇴근', '각종', '사회', '보험', '및', '퇴직금', '지급', '주차', '지원', '음료', '및', '간식', '제공', '칼퇴', '권장', '회사', '소유', '제주', '펜션', '자유', '직원', '무상', '이용', '연료', '시스템', '최적화', '평가', '및', '시험', '분석', '연료', '시스템', '개발', '관련', '업무', '연료', '에너지', '생산', '연료', '연료', '공급', '계통', '제작', '연료', '변환', '장치', '설계', '연료', '변환', '장치', '생산', '연료', '변환', '장치', '품질', '관리', '연료', '에너지', '생산', '건물', '용', '연료', '스택', '제작', '건물', '용', '연료', '스택', '설계', '건물', '용', '연료', '스택', '생산', '건물', '용', '연료', '스택', '품질', '관리', '연료', '에너지', '생산', '연료', '발', '전설', '비용', '인프라', '설계', '연료', '발전', '설비', '공급', '인프라', '설계', '연료', '발전', '설비', '내부', '인프라', '설계', '관제', '시스템', '설계', '연료', '에너지', '생산', '발', '전용', '연료', '스택', '제작', '발', '전용', '연료', '스택', '설계', '발', '전용', '연료', '스택', '생산', '발', '전용', '연료', '스택', '품질', '관리', '웹', '발인', '모집', '경력', '자동화', '장비', '미', '비씨', '프로그래머', '자동화', '비제', '경력', '터치', '작화', '가능', '전장', '회로도', '가능', '우대', '당사', '방', '산유', '무기', '검사', '및', '조립', '장비', '설계', '제작', '모듈', '공정', '장비', '설계', '제작', '업무', '카메라', '영상', '후', '처리', '및', '신호처리', '개발', '등', '이용', '제작', '영상', '보안', '개발', '시스템', '포팅', '및', '개발', '등', '제품', '셋팅및', '트러블', '슈팅', '기술', '지원', '개발', '및', '제품', '양산시', '분석', '용', '응용', '개발', '및', '자격', '조건', '관련', '개발', '경험', '있으', '신분', '상처리', '개발', '경험', '개발', '경험', '가능', '및', '네트워크', '보안', '이해', '실무', '경험', '네트워크', '통신', '개발', '경험', '포팅', '및', '개발', '환경', '개발', '경험', '장비', '프로그램', '개발', '및', '상처리', '개발', '경험', '우대', '사항', '유', '경험', '관제', '시스템', '유', '경험', '유', '경험', '등', '기반', '개발', '경험', '등', '영상', '음원', '알고리즘', '개발', '경험', '활용', '프로그램', '개발', '진취', '적극', '긍정', '유화', '마인드', '신분', '개발', '흥미', '분', '은지원', '업체', '협의', '위', '방문', '필요하므로', '운전', '가능하신', '분지', '원해주세요', '개발', '흥미', '없거나', '분석', '싫으', '신분', '죄송하지만', '지원', '보류', '스마트', '팩토리', '구축', '개발', '창고', '관리', '시스템', '개발', '선박', '부품', '업', '개발', '펌웨어', '엔지니어', '펌웨어', '개발', '및', '연구', '모집', '분야', '웹개발자', '웹', '엔지니어', '웹', '프로그래머', '담당', '업무', '웹', '개발', '웹', '프론트', '및', '앤드', '개발', '국가', '기관', '플랫폼', '개발', '및', '구축', '빅데이터', '디지털', '정보', '시스템', '개발', '및', '구축', '고객', '웹사이트', '및', '백오피스', '개발', '및', '유지', '보수', '우대', '사항', '경험', '를', '이용', '개발', '경험', '웹표준', '웹접근성', '크로스', '브라우징', '및', '활용', '경험', '반응', '모바일', '웹앱', '작업', '경험', '프로그램', '개발', '유관', '업무', '경력', '관련', '자격증', '보유', '전산학', '컴퓨터공학', '응용소프트웨어', '공학', '웹', '퍼블리싱', '위', '이해', '있으', '신분', '기획', '의도', '대해', '이해', '능력', '높으', '신분', '공통', '사항', '개발', '실무', '경력', '해외여행', '결격', '사유', '없는자', '급여', '규정', '따름', '경력', '면접', '임금', '협의', '업무', '자사', '서비스', '인기', '법무', '관리', '솔루션', '운영', '담당', '업무', '운영', '시스템', '버그', '수정', '업무', '및', '개선', '포트', '전용', '메일', '전화', '등', '통한', '담당', '우대', '조건', '주', '임금', '연봉', '개', '월계', '후', '정규직', '전환', '비', '임상시험', '관련', '데이터', '인터페이스', '위', '소프트웨어', '개발', '프레임워크', '등', '이용', '웹', '애플리케이션', '개발', '경험', '개발', '가능', '우대', '관계', '데이터베이스', '사용', '프로젝트', '경험', '등', '적극', '새로운', '기술', '플랫폼', '적응하는', '능력', '시스템', '요구사항', '정의', '기능', '추가', '수정', '삭제', '등', '위', '적절한', '기능', '개발', '서정', '경험', '가능', '경험', '우대', '사용', '가능', '우대', '당사', '제철', '협력', '사', '현대', '제철', '프로그램', '일부', '개발', '및', '운영', '유지', '보수', '업무', '이번', '프로그램', '개발', '관련', '프로그램', '사용', '경력', '채용', '경력', '연봉', '협의', '후', '결정', '전광판', '소프트웨어', '프로그램', '개발자', '회사', '소개', '셀빅', '매출', '액', '사원수', '명', '규모', '고용노동부', '선정', '강소기업', '입니다', '서울', '성동구', '성수동', '위치', '있으며', '정보통', '사업', '시스템', '네트워크', '통합', '인터', '렉티브', '콘텐츠', '기능성게임', '인공', '지능 ...

# %%
list_work2=" ".join(df["모집직종"].str.replace("\xa0","").str.replace("\r","").to_list())

icon = PIL.Image.open(r'D:\my_jupyter\EXAM_WEB_CRAWLING\project\electronic.png')
img2 = PIL.Image.new('RGB', icon.size, (255,255,255))
img2.paste(icon, icon)
img = np.array(img2)

okt =	Okt()	#	Open	Korean	Text	객체 생성
#	okt함수를 통해 읽어들인 내용의 형태소를 분석한다.
sentences_tag =	[]
sentences_tag =	okt.pos(list_work2)

noun_adj_list =	[]
#	tag가 명사이거나 형용사인 단어들만 noun_adj_list에 넣어준다.
for	word,	tag	in	sentences_tag:
    if	tag	in	['Noun'	,	'Adjective']:
        noun_adj_list.append(word)
print(noun_adj_list)
#	가장 많이 나온 단어부터 40개를 저장한다.
counts	=	Counter(noun_adj_list)
tags	=	counts.most_common(40)
tags.pop(0)

if	platform.system()	==	'Windows':
    path	=	r'C:\Users\KDP-26-\AppData\Local\Microsoft\Windows\Fonts\TENADA.ttf'
wc =	WordCloud(font_path=path,	background_color="white",	max_font_size=200,mask=img, colormap='inferno')
cloud	=	wc.generate_from_frequencies(dict(tags))

plt.figure(figsize=(20,	10))
plt.axis('off')
plt.imshow(cloud)
plt.show()
# Out:
# ['시스템소프트웨어', '개발자', '프로그래머', '시스템소프트웨어', '개발자', '프로그래머', '웹개발자', '웹', '엔지니어', '웹', '프로그래머', '산업', '특', '응용소프트웨어', '프로그래머', '국방', '항공', '교통', '에너지', '금융', '자동', '차등', '산업', '용', '전자제품', '개발', '기술자', '및', '연구원', '응용소프트웨어', '개발자', '응용소프트웨어', '개발자', '펌웨어', '및', '임베디드', '소프트웨어', '프로그래머', '웹개발자', '웹', '엔지니어', '웹', '프로그래머', '웹', '운영자', '홈페이지', '관리자', '웹개발자', '웹', '엔지니어', '웹', '프로그래머', '응용소프트웨어', '개발자', '언어', '및', '외', '프로그래밍언어', '전문가', '웹개발자', '웹', '엔지니어', '웹', '프로그래머', '기계', '금속', '도사', '캐드', '웹개발자', '웹', '엔지니어', '웹', '프로그래머', '기술', '지원', '전문가', '디자이너', '범용', '응용소프트웨어', '프로그래머', '정보처리', '재무관리', '등', '컴퓨터', '시스템', '전문가', '웹', '기획', '웹개발자', '웹개발자', '웹', '엔지니어', '웹', '프로그래머', '응용소프트웨어', '개발자', '컨설턴트', '웹개발자', '웹', '엔지니어', '웹', '프로그래머', '컴퓨터', '시스템', '설계', '및', '분석', '시스템소프트웨어', '개발자', '응용소프트웨어', '개발자', '테스', '터및', '전문가', '시스템소프트웨어', '개발자', '프로그래머', '통신', '장비', '설치', '수리', '모바일', '애플리케이션', '프로그래머', '앱', '어플', '개발', '웹', '기획', '시스템소프트웨어', '개발자', '프로그래밍언어', '전문가', '영기획', '사무', '웹개발자', '웹', '엔지니어', '웹', '프로그래머', '응용소프트웨어', '개발자', '시스템소프트웨어', '개발자', '프로그래밍언어', '전문가', '웹개발자', '웹', '엔지니어', '웹', '프로그래머', '웹개발자', '웹', '엔지니어', '웹', '프로그래머', '언어', '및', '외', '프로그래밍언어', '전문가', '프로그래밍언어', '전문가', '디자이너', '언어', '및', '외', '프로그래밍언어', '전문가', '시스템소프트웨어', '개발자', '프로그래머', '데이터', '설계', '및', '프로그래머', '컴퓨터', '시스템', '설계', '및', '분석', '언어', '및', '외', '프로그래밍언어', '전문가', '펌웨어', '및', '임베디드', '소프트웨어', '프로그래머', '웹개발자', '웹', '엔지니어', '웹', '프로그래머', '시스템소프트웨어', '개발자', '웹개발자', '시스템소프트웨어', '개발자', '펌웨어', '및', '임베디드', '소프트웨어', '프로그래머', '웹', '기획', '정보', '시스템', '운영자', '컴퓨터', '시스템', '설계', '및', '분석', '언어', '및', '외', '프로그래밍언어', '전문가', '시스템소프트웨어', '개발자', '프로그래머', '데이터', '설계', '및', '프로그래머', '모바일', '애플리케이션', '프로그래머', '앱', '어플', '개발', '웹개발자', '컴퓨터', '시스템', '설계', '및', '분석', '네트워크', '시스템', '개발자', '데이터', '전문가', '총무', '및', '일반', '사무', '웹개발자', '웹', '엔지니어', '웹', '프로그래머', '데이터', '설계', '및', '프로그래머', '시스템소프트웨어', '개발자', '프로그래머', '시스템소프트웨어', '개발자', '네트워크', '관리자', '우딩', '컴퓨터', '운영', '관리자', '웹개발자', '웹', '엔지니어', '웹', '프로그래머', '정보보안', '전문가', '기계', '제어', '기술자', '전기', '패널', '계장', '정자동', '등', '기술', '지원', '전문가', '데이터', '설계', '및', '프로그래머', '웹', '기획', '웹', '기획', '데이터', '설계', '및', '프로그래머', '웹개발자', '플라스틱', '금', '제조', '응용소프트웨어', '개발자', '기술', '지원', '전문가', '웹', '기획', '응용소프트웨어', '개발자', '시스템소프트웨어', '개발자', '프로그래밍언어', '전문가', '시스템소프트웨어', '개발자', '언어', '및', '외', '프로그래밍언어', '전문가', '프로그래밍언어', '전문가', '데이터', '설계', '및', '프로그래머', '기술', '영업', '전산', '장비', '소프트웨어', '산업', '특', '응용소프트웨어', '프로그래머', '국방', '항공', '교통', '에너지', '금융', '자동', '차등', '언어', '및', '외', '프로그래밍언어', '전문가', '웹개발자', '웹', '엔지니어', '웹', '프로그래머', '응용소프트웨어', '개발자', '웹개발자', '웹', '엔지니어', '웹', '프로그래머', '웹개발자', '기술', '지원', '전문가', '범용', '응용소프트웨어', '프로그래머', '정보처리', '재무관리', '등', '시스템소프트웨어', '개발자', '프로그래밍언어', '전문가', '웹개발자', '웹', '엔지니어', '웹', '프로그래머', '웹', '디자이너', '프로그래밍언어', '전문가', '언어', '및', '외', '프로그래밍언어', '전문가', '컴퓨터', '하드웨어', '기술자', '및', '연구원', '웹개발자', '웹', '엔지니어', '웹', '프로그래머', '웹개발자', '정보', '시스템', '운영자', '응용소프트웨어', '개발자', '금속', '기계', '부품', '조립', '웹개발자', '네트워크', '관리자', '우딩', '컴퓨터', '운영', '관리자', '기계', '금속', '도사', '캐드', '언어', '및', '외', '프로그래밍언어', '전문가', '시스템소프트웨어', '개발자', '데이터', '전문가', '데이터', '설계', '및', '프로그래머', '머', '저', '웹개발자', '웹', '엔지니어', '웹', '프로그래머', '웹개발자', '웹', '엔지니어', '웹', '프로그래머', '언어', '및', '외', '프로그래밍언어', '전문가', '기술', '지원', '전문가', '펌웨어', '및', '임베디드', '소프트웨어', '프로그래머', '언어', '및', '외', '프로그래밍언어', '전문가', '응용소프트웨어', '개발자', '모바일', '애플리케이션', '프로그래머', '앱', '어플', '개발', '컴퓨터', '시스템', '전문가', '데이터베이스', '운영', '관리자', '컴퓨터', '시스템', '설계', '및', '분석', '범용', '응용소프트웨어', '프로그래머', '정보처리', '재무관리', '등', '데이터베이스', '운영', '관리자', '전기', '기기', '제품', '개발', '기술자', '및', '연구원', '웹개발자', '웹', '엔지니어', '웹', '프로그래머', '응용소프트웨어', '개발자', '정보통', '관리자', '부서장', '응용소프트웨어', '개발자', '정보', '시스템', '운영자', '생산', '품질', '사무', '웹개발자', '웹', '엔지니어', '웹', '프로그래머', '테스', '터및', '전문가', '언어', '및', '외', '프로그래밍언어', '전문가', '웹개발자', '웹', '엔지니어', '웹', '프로그래머', '전자공학', '기술자', '및', '연구원', '펌웨어', '및', '임베디드', '소프트웨어', '프로그래머', '응용소프트웨어', '개발자', '시스템소프트웨어', '개발자', '데이터', '설계', '및', '프로그래머', '응용소프트웨어', '개발자', '웹개발자', '웹', '엔지니어', '웹', ...

# %%
fig= plt.figure(figsize=(14,7))
ax1 = fig.add_subplot(1,1,1)

sns.barplot(x=df["경력"],y=df["임금"],data=df,ax=ax1,edgecolor="black",ci=None)
ax1.set_title("경력별 연봉",size=20)
ax1.set_xlabel("경력",size=12)
ax1.set_ylabel("연봉(만원/년)",size=12)
plt.xticks(rotation=45)

for i in ax1.containers:
    ax1.bar_label(i,size=12)

plt.show()
# Out:
# C:\Users\KDP-024\AppData\Local\Temp\ipykernel_1160\1090677084.py:4: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.barplot(x=df["경력"],y=df["임금"],data=df,ax=ax1,edgecolor="black",ci=None)
