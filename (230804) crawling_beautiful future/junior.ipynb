# %%
from urllib.request import urlopen
from bs4 import BeautifulSoup
from selenium import webdriver
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import re
from matplotlib import font_manager


fe = font_manager.FontEntry(
    fname=r'C:\Users\KDP-26-\AppData\Local\Microsoft\Windows\Fonts\TENADA.ttf', # ttf 파일이 저장되어 있는 경로
    name='TENADA')                        # 이 폰트의 원하는 이름 설정
font_manager.fontManager.ttflist.insert(0, fe)              # Matplotlib에 폰트 추가
plt.rcParams.update({'font.size': 12, 'font.family': 'TENADA'}) # 폰트 설정


argument1=[]
argument2=[]
argument3=[]
argument4=[]
argument5=[]
argument6=[]
argument7=[]
argument8=[]
argument9=[]
argument10=[]
argument11=[]
argument12=[]
argument13=[]
argument14=[]
argument15=[]
argument16=[]
argument17=[]
argument18=[]
argument19=[]
argument20=[]
argument21=[]
argument22=[]
argument23=[]
argument24=[]
argument25=[]
argument26=[]

# %%
for i in range(1,11):

    html = urlopen(f"https://www.work.go.kr/empInfo/empInfoSrch/list/dtlEmpSrchList.do?careerTo=&keywordJobCd=&occupation=132000%2C025%2C024%2C023&templateInfo=&shsyWorkSecd=&rot2WorkYn=&payGbn=&resultCnt=10&keywordJobCont=&cert=&cloDateStdt=&moreCon=&minPay=&codeDepth2Info=11000&isChkLocCall=&sortFieldInfo=DATE&major=&resrDutyExcYn=&eodwYn=&sortField=DATE&staArea=&sortOrderBy=DESC&keyword=&termSearchGbn=all&carrEssYns=&benefitSrchAndOr=O&disableEmpHopeGbn=&webIsOut=&actServExcYn=&maxPay=&keywordStaAreaNm=&emailApplyYn=&listCookieInfo=DTL&pageCode=&codeDepth1Info=11000&keywordEtcYn=&publDutyExcYn=&keywordJobCdSeqNo=&exJobsCd=&templateDepthNmInfo=&computerPreferential=&regDateStdt=&employGbn=&empTpGbcd=1&region=&infaYn=&resultCntInfo=10&siteClcd=WORK&cloDateEndt=&sortOrderByInfo=DESC&currntPageNo=1&indArea=&careerTypes=N&searchOn=Y&tlmgYn=&subEmpHopeYn=&academicGbn=&templateDepthNoInfo=&foriegn=&mealOfferClcd=&station=&moerButtonYn=Y&holidayGbn=&srcKeyword=&enterPriseGbn=all&academicGbnoEdu=noEdu&cloTermSearchGbn=all&keywordWantedTitle=&stationNm=&benefitGbn=&keywordFlag=&notSrcKeyword=&essCertChk=&isEmptyHeader=&depth2SelCode=&_csrf=7bd1e995-f2e8-4b8e-8400-046e4729bbf0&keywordBusiNm=&preferentialGbn=&rot3WorkYn=&pfMatterPreferential=&regDateEndt=&staAreaLineInfo1=11000&staAreaLineInfo2=1&pageIndex={i}&termContractMmcnt=&careerFrom=&laborHrShortYn=#viewSPL")
    soup = BeautifulSoup(html,features="lxml")
    
    a_list = soup.select("div.cp-info-in > a")

    for i in a_list:

        sites = "https://www.work.go.kr" + i["href"]
      
        html2 = urlopen(sites)
        soup2 = BeautifulSoup(html2,features="lxml")
        
        list1 = soup2.select("#contents > section > div > div.careers-area > div.careers-new > div.border > div.left")
        for i in list1:
            argument1.append(i.select_one("div:nth-child(3) > div  div > ul > li span").text.strip().replace("\n","").replace("\t","").replace(" ",""))
            argument2.append(i.select_one("div:nth-child(2) > div:nth-child(1) > div > ul > li:nth-child(2) > span").text.strip().replace("\n","").replace("\t","").replace(" ",""))
            argument3.append(i.select_one("div:nth-child(2) > div:nth-child(2) > div > ul > li:nth-child(1) > span").text.strip().replace("\n","").replace("\t","").replace(" ",""))
            argument4.append(i.select_one("div:nth-child(2) > div:nth-child(2) > div > ul > li:nth-child(2) > span").text.strip().replace("\n","").replace("\t","").replace(" ",""))
            argument5.append(i.select_one("div:nth-child(3) > div:nth-child(1) > div > ul > li:nth-child(1) > span").text.strip().replace("\n","").replace("\t","").replace(" ",""))
            argument6.append(i.select_one("div:nth-child(3) > div:nth-child(1) > div > ul > li:nth-child(2) > span").text.strip().replace("\n","").replace("\t","").replace(" ",""))
            argument7.append(i.select_one("div:nth-child(3) > div:nth-child(2) > div > ul > li").text.strip().replace("\n","").replace("\t","").replace(" ",""))
        list2= soup2.select("#contents > section > div > div.careers-area > div.careers-new > div.border > div.right")
        for i in list2:
            argument8.append(i.select_one("div.info > ul > li:nth-child(1) > div").text.strip().replace("\n","").replace("\t","").replace(" ",""))
            argument9.append(i.select_one("div.info > ul > li:nth-child(2) > div").text.strip().replace("\n","").replace("\t","").replace(" ",""))
            argument10.append(i.select_one("div.info > ul > li:nth-child(3) > div").text.strip().replace("\n","").replace("\t","").replace(" ",""))
            argument11.append(i.select_one("div.info > ul > li:nth-child(4) > div").text.strip().replace("\n","").replace("\t","").replace(" ",""))
            argument12.append(i.select_one("div.info > ul > li:nth-child(5) > div").text.strip().replace("\n","").replace("\t","").replace(" ",""))
            argument13.append(i.select_one("div.info > ul > li:nth-child(6) > div").text.strip().replace("\n","").replace("\t","").replace(" ",""))
            argument14.append(i.select_one("div.info > ul > li:nth-child(7) > div").text.strip().replace("\n","").replace("\t","").replace(" ",""))
        argument15.append(soup2.select_one("#contents > section > div > div.careers-area > div:nth-child(4) > table > tbody > tr > td").text.strip().replace("\n","").replace("\t","").replace(" ",""))
        argument16.append(soup2.select_one("div.careers-area > div:nth-child(6) > table tr > td:nth-child(1)").text.strip().replace("\n","").replace("\t","").replace(" ",""))
        argument17.append(soup2.select_one("#contents > section > div > div.careers-area > div:nth-child(6) > table > tbody > tr > td:nth-child(3)").text.strip().replace("\n","").replace("\t","").replace(" ",""))
        argument18.append(soup2.select_one("#contents > section > div > div.careers-area > div:nth-child(14) > table > tbody > tr > td:nth-child(1)").text.strip().replace("\n","").replace("\t","").replace(" ",""))
        argument19.append(soup2.select_one("#contents > section > div > div.careers-area > div:nth-child(14) > table > tbody > tr > td:nth-child(2)").text.strip().replace("\n","").replace("\t","").replace(" ",""))
        argument20.append(soup2.select_one("#contents > section > div > div.careers-area > div:nth-child(14) > table > tbody > tr > td:nth-child(3)").text.strip().replace("\n","").replace("\t","").replace(" ",""))
        argument21.append(soup2.select_one("#contents > section > div > div.careers-area > div:nth-child(14) > table > tbody > tr > td:nth-child(4)").text.strip().replace("\n","").replace("\t","").replace(" ",""))
        argument22.append(soup2.select_one("#contents > section > div > div.careers-area > div:nth-child(14) > table > tbody > tr > td:nth-child(5)").text.strip().replace("\n","").replace("\t","").replace(" ",""))
        argument23.append(soup2.select_one("#contents > section > div > div.careers-area > div.careers-table.cnts.v1.mt20 > table > tbody > tr:nth-child(2) td:nth-child(1)").text.strip().replace("\n","").replace("\t","").replace(" ",""))
        argument24.append(soup2.select_one("#contents > section > div > div.careers-area > div.careers-table.cnts.v1.mt20 > table > tbody > tr:nth-child(2) td:nth-child(2)").text.strip().replace("\n","").replace("\t","").replace(" ",""))
        argument25.append(soup2.select_one("#contents > section > div > div.careers-area > div.careers-table.cnts.v1.mt20 > table > tbody > tr:nth-child(4) td:nth-child(1)").text.strip().replace("\n","").replace("\t","").replace(" ",""))
        argument26.append(soup2.select_one("#contents > section > div > div.careers-area > div.careers-table.cnts.v1.mt20 > table > tbody > tr:nth-child(4) td:nth-child(2)").text.strip().replace("\n","").replace("\t","").replace(" ",""))
        soup.select


total_list = [argument1,argument2,argument3,argument4,argument5,argument6,argument7,argument8,argument9,argument10,argument11,argument12,argument13,argument14,argument15,argument16,argument17,argument18,argument19,argument20,argument21,argument22,argument23,argument24,argument25,argument26]

df = pd.DataFrame(total_list,index=['경력','학력','지역','임금','고용형태',
        '근무형태','복리후생','기업명','업종','기업규모',
        '설립년도','연매출액','홈페이지','근로자수','직무내용',
        '모집직종','관련직종','전공','자격면허','외국어능력',
        '병역대체 복무자채용','고용허가제','우대조건','컴퓨터 활용능력','기타우대사항',
        '작업환경'])

df=df.T

# %%
# 경력 수정 필요X, 모두 신입 확인
df["경력"].value_counts()
# Out:
# 신입    97
# Name: 경력, dtype: int64

# %%
# 학력
df["학력"].value_counts()
# Out:
# 학력무관               32
# 대졸(2~3년)~대졸(4년)    28
# 대졸(4년)             11
# 고졸~대졸(4년)           5
# 대졸(4년)~석사           5
# 대졸(2~3년)~석사         4
# 대졸(2~3년)            4
# 대졸(4년)~박사           3
# 고졸~석사               2
# 대졸(2~3년)~박사         2
# 고졸~박사               1
# Name: 학력, dtype: int64

# %%
# 학력무관이면 그냥 출력, 다른 경우는 학력 최저기준을 기준으로 출력

def edu_slice(str1):
    if str1!="학력무관":
        return str1[:2]+"이상"
    else:
        return str1
# 학력 재분류
df["학력"]=df["학력"].apply(edu_slice)

# %%
df["학력"].value_counts()
# Out:
# 대졸이상    57
# 학력무관    32
# 고졸이상     8
# Name: 학력, dtype: int64

# %%
# 지역은 너무 세부적으로 있으니 도별로 구분
df["지역"]
# Out:
# 0       서울특별시금천구가산디지털1로219,벽산디지털밸리6차706-1호(가산동)
# 1           경기도고양시일산동구호수로358-39,동문타워1차907호(백석동)
# 2        대구광역시서구와룡로307,822호,(중리동,디센터1976지식산업센터)
# 3                      대전광역시서구만년로79,가원빌딩7층(만년동)
# 4           경기도성남시중원구양현로405번길4-11,9층(여수동,유아이빌딩)
#                         ...
# 92              전라남도순천시중앙로235,국제문화컨벤션관305호(매곡동)
# 93                     전라남도나주시그린로379,210동(빛가람동)
# 94                 서울특별시중구을지로264,11층스파크플러스1117호
# 95                   서울특별시송파구법원로128,SKV1C동1210호
# 96    경기도안양시동안구벌말로123,A동1105호(관양동,평촌스마트베이)(관양동)
# Name: 지역, Length: 97, dtype: object

# %%
df["지역"]=df["지역"].str.replace("도","도 ").str.replace("시","시 ").str.split(" ").str[0]

# %%
df["지역"].value_counts()
# Out:
# 서울특별시      34
# 경기도        27
# 경상남도        6
# 전라남도        6
# 경상북도        5
# 대전광역시       4
# 대구광역시       3
# 광주광역시       3
# 전라북도        2
# 충청북도        2
# 부산광역시       2
# 인천광역시       1
# 충청남도        1
# 세종특별자치시     1
# Name: 지역, dtype: int64

# %%
df["임금"].str.replace("연봉","").str.replace("월급","").str.replace("만원","").str.replace("이상","").str.replace(",","").str.split("~")
# Out:
# 0           [2600]
# 1           [2800]
# 2     [2800, 3000]
# 3     [2500, 3000]
# 4           [2500]
#           ...
# 92           [220]
# 93    [2700, 3000]
# 94          [3000]
# 95    [2760, 3480]
# 96    [2550, 2800]
# Name: 임금, Length: 97, dtype: object

# %%
# 임금 부분을 숫자로 변경 및 평균으로 변경하는 함수
def wage_avg(list1):
    
    if int(list1[0])>1000:
        if len(list1)==1:
            return int(list1[0])
        else:
            wage =int((int(list1[0])+int(list1[1]))/2)
            return wage
    elif int(list1[0])<1000:
        if len(list1)==1:
            return int(list1[0])*12
        else:
            wage =int((int(list1[0])+int(list1[1]))/2)*12
            return wage

# %%
# 수치형 데이터로 변경
df["임금"]=df["임금"].str.replace("연봉","").str.replace("월급","").str.replace("만원","").str.replace("이상","").str.replace(",","").str.split("~").apply(wage_avg)

# %%
df["임금"].value_counts().sort_index()
# Out:
# 1812     1
# 2412     2
# 2413     1
# 2416     1
# 2500     2
# 2544     1
# 2600     2
# 2640     2
# 2646     1
# 2675     1
# 2700     3
# 2725     2
# 2750     4
# 2760     2
# 2800     6
# 2820     1
# 2850     5
# 2880     1
# 2900     7
# 2940     1
# 2975     1
# 3000    21
# 3048     1
# 3085     1
# 3100     1
# 3120     1
# 3180     3
# 3200     3
# 3250     1
# 3325     2
# 3360     1
# 3400     2
# 3500     2
# 3600     3
# 3720     1
# 4000     1
# 4150     1
# 4250     1
# 4300     2
# 4400     1
# 4800     1
# Name: 임금, dtype: int64

# %%
# 고용형태는 기간 유무로만 구분 필요
df["고용형태"].value_counts()
# Out:
# 기간의정함이없는근로계약             84
# 기간의정함이있는근로계약             12
# 기간의정함이없는근로계약(시간(선택)제)     1
# Name: 고용형태, dtype: int64

# %%
df["고용형태"]=df["고용형태"].str.replace("\(시간\(선택\)제\)","")
# Out:
# C:\Users\KDP-26-\AppData\Local\Temp\ipykernel_11864\3589070156.py:1: FutureWarning: The default value of regex will change from True to False in a future version.
#   df["고용형태"]=df["고용형태"].str.replace("\(시간\(선택\)제\)","")

# %%
df["고용형태"].value_counts()
# Out:
# 기간의정함이없는근로계약    85
# 기간의정함이있는근로계약    12
# Name: 고용형태, dtype: int64

# %%
# 근무형태는 변경필요 X
df["근무형태"].value_counts()
# Out:
# 주5일근무    97
# Name: 근무형태, dtype: int64

# %%
# 복리후생
df['복리후생']
# Out:
# 0          식사제공(1식)
# 1
# 2       식사제공(중식비지급)
# 3
# 4     교육비제공식사제공(1식)
#           ...
# 92
# 93
# 94         식사제공(3식)
# 95
# 96         식사제공(1식)
# Name: 복리후생, Length: 97, dtype: object

# %%
# 기업명에 있던 "(주)" 및 "주식회사" 제거

df["기업명"]=df["기업명"].str.replace("주식회사","").str.replace("\(주\)","")
# Out:
# C:\Users\KDP-26-\AppData\Local\Temp\ipykernel_11864\2541823816.py:3: FutureWarning: The default value of regex will change from True to False in a future version.
#   df["기업명"]=df["기업명"].str.replace("주식회사","").str.replace("\(주\)","")

# %%
# 업종
df["업종"].value_counts()
# Out:
# 컴퓨터프로그래밍서비스업             14
# 컴퓨터시스템통합자문및구축서비스업        12
# 응용소프트웨어개발및공급업            11
# 시스템소프트웨어개발및공급업            7
# 소프트웨어개발및공급업               7
# 그외기타분류안된전문,과학및기술서비스업      4
# 전자상거래소매업                  4
# 시스템ㆍ응용소프트웨어개발및공급업         4
# 배전반및전기자동제어반제조업            3
# 컴퓨터및주변장치,소프트웨어도매업         2
# 기타무선통신장비제조업               2
# 기타전문서비스업                  2
# 그외기타의료용기기제조업              2
# 건축설계및관련서비스업               1
# 주형및금형제조업                  1
# 기타게임소프트웨어개발및공급업           1
# 기타엔지니어링서비스업               1
# 방사선장치제조업                  1
# 일반용전기조명장치제조업              1
# 광고대행업                     1
# 철도여객운송업                   1
# 반도체제조용기계제조업               1
# 산업용로봇제조업                  1
# 금속단조,압형및분말야금제품제조업         1
# 컴퓨터제조업                    1
# 전기장비제조업                   1
# 그외기타교육기관                  1
# 그외기타협회및단체                 1
# 정보서비스업                    1
# 그외기타전자부품제조업               1
# 다이오드,트랜지스터및유사반도체소자제조업     1
# 그외기타생활용품도매업               1
# 육류기타가공및저장처리업(가금류제외)       1
# 기타수산동물가공및저장처리업            1
# 그외기타전기장비제조업               1
# 기타정보기술및컴퓨터운영관련서비스업        1
# Name: 업종, dtype: int64

# %%
# 규모
df["기업규모"].value_counts()
# Out:
# 중소기업    83
#         12
# 기타       2
# Name: 기업규모, dtype: int64

# %%
# 설립년도 공백 -> 0으로 처리
# ~년도 삭제
# int로 형변환
df["설립년도"]=df["설립년도"].str[:4].replace("",0).apply(lambda x :int(x))

# %%
df["설립년도"].value_counts()
# Out:
# 0       22
# 2007     8
# 2020     6
# 2011     5
# 2015     5
# 2017     4
# 2014     4
# 2019     4
# 2018     4
# 2021     4
# 2016     3
# 2004     3
# 1984     3
# 2002     3
# 2010     3
# 2012     2
# 2003     2
# 1996     2
# 2006     1
# 2009     1
# 1976     1
# 2013     1
# 1987     1
# 2000     1
# 2022     1
# 1998     1
# 1999     1
# 2005     1
# Name: 설립년도, dtype: int64

# %%
df["연매출액"].str.replace(",","").str.replace("백만원","").value_counts()
# Out:
#           28
# 3000       5
# 2000       4
# 1000       4
# 21         3
# 700        2
# 500        2
# 6000       2
# 624        2
# 4000       2
# 400        2
# 28552      1
# 2500       1
# 1104       1
# 8000       1
# 8586       1
# 435        1
# 67         1
# 3132       1
# 3708       1
# 730        1
# 1720       1
# 25670      1
# 2300       1
# 900        1
# 2045       1
# 600        1
# 50000      1
# 931        1
# 2200       1
# 3927       1
# 791        1
# 4400       1
# 2236       1
# 36000      1
# 1700       1
# 6170       1
# 1990       1
# 4277       1
# 100000     1
# 2130       1
# 98         1
# 749        1
# 8670       1
# 7100       1
# 710        1
# 367        1
# 18170      1
# 300000     1
# 2100       1
# 4317       1
# 1071       1
# Name: 연매출액, dtype: int64

# %%
for i in range(df.shape[0]):
    if df.loc[i,"연매출액"] =="":
        df.loc[i,"연매출액"] = 0
    else:
        df.loc[i,"연매출액"]= int(df.loc[i,"연매출액"].replace(",","").replace("백만원",""))

# %%
df["연매출액"]
# Out:
# 0         0
# 1         0
# 2      3000
# 3         0
# 4      3000
#       ...
# 92        0
# 93    50000
# 94        0
# 95      931
# 96     1071
# Name: 연매출액, Length: 97, dtype: object

# %%
#쓰지 못하는 데이터 변겅
df["홈페이지"]
# Out:
# 0                 www.gdsys.co.kr
# 1                               -
# 2                 www.wizis.co.kr
# 3                               -
# 4                  safesoft.co.kr
#                  ...
# 92                     sd-tech.kr
# 93    http://www.teraenergy.co.kr
# 94           www.aceproject.co.kr
# 95           www.jksolution.co.kr
# 96             www.jcastnet.co.kr
# Name: 홈페이지, Length: 97, dtype: object

# %%
# 근로자수 수치형으로 변경
df["근로자수"]=df["근로자수"].str.replace("명","").apply(lambda x: int(x))

# %%
# 형태소
df["직무내용"].str.contains("SQL").sum()
# Out:
# 12

# %%
df["직무내용"]
# Out:
# 0     직무내용 - "IT인프라 구축,정비 등 기술지원"\r- IDC 인프라 운영 및 관리...
# 1                                       웹 개발\r - 프론트 개발
# 2     C# 활용, Java, Visual Basic  프로그램 개발 \r1. 진취적이고,...
# 3     업무 : JSP 웹 개발 및 유지관리 업무\r         공공기관 개발 및 유지...
# 4     * 임상, 비임상 및 바이오 관련 개발 소프트웨어의 검증 ( S/W Validati...
#                             ...
# 92    AI 및 빅데이터 \r소프트웨어 및 하드웨어 개발\r데이터 분석 및 패턴과 인사이트...
# 93    <직무내용>\r응용SW개발자\r-스마트시티, 스마트팩토리 분야 빅테이터 솔루션 데이...
# 94    <직무내용>\r- 야구 매니지먼트 게임 기획\r- 게임 내 각 종 콘텐츠, 시스템 ...
# 95    # 고객 관련된 솔루션 설치 지원 및 설치한 제품 유지 관리 지원.\r 1. 백업 ...
# 96    Windows 기반 C#, Python, SQL 등으로 스마트공장 및 AI솔루션 SW개발
# Name: 직무내용, Length: 97, dtype: object

# %%
# 직종

df["모집직종"].value_counts()
# Out:
# IT기술지원전문가                         17
# 응용소프트웨어개발자                        14
# 웹개발자(웹엔지니어·웹프로그래머)                11
# 시스템소프트웨어개발자                        7
# IT테스터및ITQA전문가                      5
# 웹개발자                               5
# 웹운영자(홈페이지관리자)                      4
# C언어및그외프로그래밍언어전문가                   4
# 펌웨어및임베디드소프트웨어프로그래머                 3
# 데이터설계및프로그래머                        3
# 정보시스템운영자                           3
# 범용응용소프트웨어프로그래머(ERP,정보처리,재무관리등)     2
# 네트워크관리자(클라우딩컴퓨터운영관리자)              2
# 웹기획자                               2
# 전기계측제어기술자(전기패널,계장,공정자동화전기등)        2
# 시스템소프트웨어개발자(프로그래머)                 2
# 로봇공학기술자및연구원                        2
# 웹디자이너                              1
# 관제사(항공,선박,철도등)                     1
# 데이터분석가(빅데이터분석가)                    1
# 고객상담원(A/S·고장·제품사용)                 1
# 전자제어계측기술자및연구원                      1
# JAVA프로그래밍언어전문가                     1
# 컴퓨터시스템설계및분석가                       1
# 데이터전문가                             1
# 기타정보통신기기설치·수리원                     1
# Name: 모집직종, dtype: int64

# %%
# 빈데이터가 많음
df["관련직종"].value_counts()
# Out:
#                                                  43
# IT기술지원전문가                                         4
# 응용소프트웨어개발자                                        4
# 시스템소프트웨어개발자(프로그래머)                                4
# 정보시스템운영자                                          3
# C언어및그외프로그래밍언어전문가                                  3
# 웹개발자(웹엔지니어·웹프로그래머)                                3
# 시스템소프트웨어개발자(프로그래머),응용소프트웨어개발자                     2
# 웹개발자                                              2
# IT테스터및ITQA전문가                                     2
# 데이터전문가,데이터베이스운영·관리자                               2
# 시스템소프트웨어개발자,컴퓨터하드웨어기술자및연구원                        1
# 기계·금속제도사(캐드원)                                     1
# 전자제어계측기술자및연구원,시스템소프트웨어개발자(프로그래머)                  1
# C언어및그외프로그래밍언어전문가,모바일애플리케이션프로그래머(앱·어플개발)           1
# 정보보안전문가                                           1
# JAVA프로그래밍언어전문가,시스템소프트웨어개발자                        1
# 컴퓨터시스템설계및분석가,전자공학기술자및연구원                          1
# 시스템소프트웨어개발자,UX/UI디자이너                             1
# 마케팅·광고·홍보·상품기획사무원,마케팅전문가                          1
# 전자부품개발기술자및연구원,가스·에너지공학기술자및연구원                     1
# IT기술지원전문가,네트워크관리자(클라우딩컴퓨터운영관리자)                   1
# JAVA프로그래밍언어전문가,범용응용소프트웨어프로그래머(ERP,정보처리,재무관리등)     1
# 펌웨어및임베디드소프트웨어프로그래머,C언어및그외프로그래밍언어전문가               1
# IT기술영업원(전산장비,소프트웨어)                               1
# JAVA프로그래밍언어전문가,웹개발자                               1
# 정보보안전문가,시스템소프트웨어개발자(프로그래머)                        1
# 데이터분석가(빅데이터분석가),응용소프트웨어개발자                        1
# 응용소프트웨어개발자,시스템소프트웨어개발자(프로그래머)                     1
# 펌웨어및임베디드소프트웨어프로그래머,시스템소프트웨어개발자(프로그래머)             1
# 쇼핑몰택배준비원                                          1
# 응용소프트웨어개발자,C언어및그외프로그래밍언어전문가                       1
# 전기·전자장비제도사(캐드원)                                   1
# 모바일애플리케이션프로그래머(앱·어플개발)                            1
# JAVA프로그래밍언어전문가,응용소프트웨어개발자                         1
# 응용소프트웨어개발자,시스템소프트웨어개발자                            1
# Name: 관련직종, dtype: int64

# %%
# 안쓰는 데이터
df["전공"].value_counts()
# Out:
#                                                      40
# 전산학·컴퓨터공학(학과:컴퓨터공학계열)                                 3
# 전산학·컴퓨터공학(학과:전산학전공)정보·통신공학(학과:전자ㆍ정보통신공학부)             2
# 전산학·컴퓨터공학(학과:컴퓨터공학과)응용소프트웨어공학(학과:컴퓨터소프트웨어공학전공)        2
# 전산학·컴퓨터공학(학과:컴퓨터공학과)정보·통신공학(학과:전기전자정보통신공학)            1
# 전자공학전산학·컴퓨터공학(학과:컴퓨터공학계열)                             1
# 전산학·컴퓨터공학(학과:IT정보공학부(컴퓨터시스템공학,소프트웨어공학))               1
# 응용소프트웨어공학(학과:컴퓨터소프트웨어ㆍ정보통신전공)정보·통신공학(학과:정보통신계열)       1
# 응용소프트웨어공학(학과:소프트웨어공학과)                                1
# 전산학·컴퓨터공학(학과:컴퓨터공학과군)                                 1
# 응용소프트웨어공학(학과:소프트웨어개발전공)응용소프트웨어공학(학과:컴퓨터소프트웨어공학전공)     1
# 전기공학(학과:전기공학과)전기공학(학과:전기ㆍ컴퓨터공학부)                      1
# 전산학·컴퓨터공학(학과:컴퓨터공학과)                                  1
# 건축·설비공학(학과:건축컴퓨터공학과군)                                 1
# 전산학·컴퓨터공학(학과:컴퓨터공학과)응용소프트웨어공학(학과:소프트웨어전공)             1
# 전산학·컴퓨터공학(학과:공과대학컴퓨터공학과)                              1
# 정보·통신공학(학과:네트워크전공)정보·통신공학(학과:컴퓨터정보학과)                 1
# 응용소프트웨어공학(학과:컴퓨터공학부(컴퓨터공학))정보·통신공학(학과:정보처리전공)         1
# 정보·통신공학(학과:데이터베이스응용공학전공)정보·통신공학(학과:IT정보공학과)           1
# 응용소프트웨어공학(학과:소프트웨어전공)                                 1
# 전자공학(학과:전기전자제어공학부)응용소프트웨어공학(학과:전자소프트웨어학전공)            1
# 정보·통신공학(학과:정보통신계열)                                    1
# 전산학·컴퓨터공학(학과:컴퓨터계열)정보·통신공학(학과:정보통신계열)                 1
# 전산학·컴퓨터공학(학과:컴퓨터공학계열)응용소프트웨어공학(학과:소프트웨어공학과)           1
# 전자공학(학과:컴퓨터·정보통신공학전공)                                 1
# 전자공학(학과:공과대학전자공학과)에너지공학(학과:에너지공학부신재생에너지전공)            1
# 전산학·컴퓨터공학(학과:컴퓨터공학과)전자공학(학과:전자공학컴퓨터학계열)               1
# 디자인일반(학과:디자인(공통))                                     1
# 응용소프트웨어공학(학과:응용소프트웨어공학)전산학·컴퓨터공학(학과:전산학·컴퓨터공학)        1
# 전산학·컴퓨터공학(학과:전산학과)전산학·컴퓨터공학(학과:전산전자공학부)               1
# 전산학·컴퓨터공학(학과:컴퓨터계열)                                   1
# 전산학·컴퓨터공학응용소프트웨어공학(학과:소프트웨어공학부)                       1
# 전산학·컴퓨터공학(학과:컴퓨터·IT공학부(전산공학전공))                       1
# 전산학·컴퓨터공학(학과:컴퓨터공학부)                                  1
# 전산학·컴퓨터공학정보·통신공학                                      1
# 정보·통신공학(학과:IT계열)                                      1
# 전자공학(학과:반도체전자공학전공)                                    1
# 응용소프트웨어공학(학과:소프트웨어개발전공)정보·통신공학(학과:모바일어플리케이션개발학과)      1
# 응용소프트웨어공학(학과:컴퓨터공학부(컴퓨터공학))응용공학(학과:시스템공학과)            1
# 전기공학(학과:전기·제어공학부)                                     1
# 응용소프트웨어공학(학과:소프트웨어개발전공)                               1
# 전산학·컴퓨터공학(학과:전산공학전공)                                  1
# 전자공학(학과:컴퓨터·전자공학부)                                    1
# 전산학·컴퓨터공학(학과:컴퓨터공학과)수학(학과:전산수학과)                      1
# 전산학·컴퓨터공학(학과:컴퓨터공학과)전산학·컴퓨터공학(학과:인공지능전공)              1
# 정보·통신공학(학과:네트워크전공)정보·통신공학(학과:정보통신공학계열)                1
# 정보·통신공학(학과:IT정보공학과)응용소프트웨어공학(학과:IT융합응용공학과)            1
# 수산학(학과:수산가공학전공)통계학(학과:물류통계정보학과)                       1
# 기계공학(학과:CAD/CAM전공)전산학·컴퓨터공학(학과:컴퓨터&인터넷공학전공)           1
# 정보·통신공학(학과:전자ㆍ전자통신ㆍ컴퓨터공학부)정보·통신공학(학과:컴퓨터통신공학과)        1
# 전산학·컴퓨터공학(학과:컴퓨터공학과)전자공학(학과:전기전자공학과)                  1
# 전산학·컴퓨터공학(학과:전산학과)정보·통신공학(학과:컴퓨터및정보통신공학부)             1
# 응용소프트웨어공학(학과:소프트웨어공학부)전자공학(학과:전자·컴퓨터·전기·제어공학부)        1
# 전산학·컴퓨터공학(학과:컴퓨터전공)전자공학(학과:전기전자공학계열)                  1
# Name: 전공, dtype: int64

# %%
# df["자격면허"].str.contains("데이터").sum()
df["자격면허"]
# Out:
# 0     정보처리기사(우대),정보처리산업기사(우대)기타:CCNA,CCNP
# 1                              정보처리기사(우대)
# 2                                    관계없음
# 3                              정보처리기사(우대)
# 4                                    관계없음
#                      ...
# 92                     기타:IT관련전공자및IT관련자격증
# 93      정보처리기사(우대),시각디자인기사(우대)기타:해당산업기사포함
# 94                                   관계없음
# 95                                   관계없음
# 96                             정보처리기사(우대)
# Name: 자격면허, Length: 97, dtype: object

# %%
# 사용 X

df["외국어능력"].value_counts()
# Out:
#          91
# 영어(중)     3
# 영어(하)     2
# 영어(상)     1
# Name: 외국어능력, dtype: int64

# %%
# 의미없는 데이터
df["병역대체 복무자채용"].value_counts()
# Out:
# 비희망                  96
# 희망(보충역대상자/산업기능요원)     1
# Name: 병역대체 복무자채용, dtype: int64

# %%
# 의미없는 데이터
df["고용허가제"].value_counts()
# Out:
#                              96
# 내국인구인노력기간이후고용허가제대상외국인채용예정     1
# Name: 고용허가제, dtype: int64

# %%
df["우대조건"].value_counts()
# Out:
#                                                                   62
# 운전면허증                                                             18
# 차량소지자,운전면허증                                                        6
# 차량소지자                                                              3
# 고용촉진장려금대상자                                                         3
# 고용촉진장려금대상자,운전면허증                                                   2
# 보훈취업지원대상자                                                          1
# (준)고령자(50세이상),북한이탈주민,장기복무제대군인,고용촉진장려금대상자,보훈취업지원대상자,차량소지자,운전면허증     1
# 고용촉진장려금대상자,차량소지자,운전면허증                                             1
# Name: 우대조건, dtype: int64

# %%
df["컴퓨터 활용능력"].value_counts()
# Out:
#                                                                                                              62
# 문서작성 (워드프로세스 활용),표계산 (스프레드시트 활용)  ,프레젠테이션 프로그램 활용                                                            16
# 문서작성 (워드프로세스 활용)                                                                                              8
# 문서작성 (워드프로세스 활용),표계산 (스프레드시트 활용)  ,프레젠테이션 프로그램 활용,회계프로그램                                                      4
# 문서작성 (워드프로세스 활용),프레젠테이션 프로그램 활용                                                                               2
# 기타(-컴퓨터/시스템 공학을 전공하신 분\r-정보처리기사 자격증을 취득하신 분)                                                                  1
# 문서작성 (워드프로세스 활용),회계프로그램                                                                                       1
# 프레젠테이션 프로그램 활용                                                                                                1
# 문서작성 (워드프로세스 활용),표계산 (스프레드시트 활용)  ,회계프로그램,기타 (문서관리 관련 자격소지자 우대)                                               1
# 문서작성 (워드프로세스 활용),표계산 (스프레드시트 활용)  ,프레젠테이션 프로그램 활용,기타 (Python, C/C++ , Pytorch, Tensorflow, Keras 등 프레임워크)     1
# Name: 컴퓨터 활용능력, dtype: int64

# %%
df["기타우대사항"].str.contains("").sum()
# Out:
# 97

# %%
# 의미 없는 데이터
df["작업환경"].value_counts()
# Out:
#                                                                                               94
# 작업장소:실내서거나걷기:서거나걷는일거의없음듣고말하기:듣고말하기중요                                                           1
# 작업장소:실내ㆍ외                                                                                      1
# 작업장소:실내드는힘:5Kg이내의물건을다룸서거나걷기:서거나걷는일거의없음듣고말하기:듣고말하는작업거의없음시력:일상적인활동이가능한정도손작업:정밀한작업양손사용:양손으로작업     1
# Name: 작업환경, dtype: int64

# %%
df.sort_values(by='자격면허',inplace=True,ignore_index=True)
df2=df

# %%
df = df.assign(sqlp=df['자격면허'].apply(lambda x: 'SQLP(SQL전문가)' in x))
df = df.assign(a=df['자격면허'].apply(lambda x: '정보처리기사' in x))
df = df.assign(b=df['자격면허'].apply(lambda x: '정보통신기사' in x))
df = df.assign(c=df['자격면허'].apply(lambda x: '전기' in x))#
df = df.assign(d=df['자격면허'].apply(lambda x: '리눅스' in x))
df = df.assign(e=df['직무내용'].str.lower().apply(lambda x: 'c' in x))
df = df.assign(f=df['직무내용'].str.lower().apply(lambda x: 'java' in (' ' + x + ' ')))
df = df.assign(g=df['직무내용'].str.lower().apply(lambda x: 'javascript' in (' ' + x + ' ')))
df = df.assign(h=df['직무내용'].str.lower().apply(lambda x: 'html' in (' ' + x + ' ')))
df = df.assign(i=df['직무내용'].str.lower().apply(lambda x: 'python' in (' ' + x + ' ') or '파이썬' in (' ' + x + ' ')))

# %%
for i in range(df.shape[0]):
    if 'SQLP(SQL전문가)' in  df.loc[i,"자격면허"]:
        df.loc[i,"면허종류"] = 'SQLP(SQL전문가)'
    elif '정보처리기사' in  df.loc[i,"자격면허"]:
        df.loc[i,"면허종류"] = '정보처리기사'
    elif '정보통신기사' in  df.loc[i,"자격면허"]:
        df.loc[i,"면허종류"] = '정보통신기사'
    elif '전기' in  df.loc[i,"자격면허"]:
        df.loc[i,"면허종류"] = '전기기사'
    else:
        df.loc[i,"면허종류"] = False

# %%
fig= plt.figure(figsize=(20,7))
ax1 = fig.add_subplot(1,3,1)
ax2 = fig.add_subplot(1,3,2)
ax3 = fig.add_subplot(1,3,3)
contrast_colors = sns.color_palette("Dark2")
sns.barplot(x=["정보처리기사 자격증 O","정보처리기사 자격증 X"], y= [df.loc[df["a"],"임금"].mean(),df.loc[~df["a"],"임금"].mean()],palette=contrast_colors,ax=ax1,edgecolor="black")
ax1.set_title("정보처리기사 자격증에 따른 연봉",size=20)
ax1.set_xlabel("정보처리기사 자격증 유무",size=12)
ax1.set_ylabel("연봉(만원/년)",size=12)
for i in ax1.containers:
    ax1.bar_label(i,size=12)
ax1.bar_label


sns.barplot(x=["정보통신기사 자격증 O","정보통신기사 자격증 X"], y= [df.loc[df["b"],"임금"].mean(),df.loc[~df["b"],"임금"].mean()],palette=contrast_colors,ax=ax2,edgecolor="black")
ax2.set_title("정보통신기사 자격증에 따른 연봉",size=20)
ax2.set_xlabel("정보통신기사 자격증 유무",size=12)
ax2.set_ylabel("연봉(만원/년)",size=12)
for i in ax2.containers:
    ax2.bar_label(i,size=12)
ax2.bar_label

sns.barplot(x=["전기기사 자격증 O","전기기사 자격증 X"], y= [df.loc[df["c"],"임금"].mean(),df.loc[~df["c"],"임금"].mean()],palette=contrast_colors,ax=ax3,edgecolor="black")
ax3.set_title("전기기사 자격증에 따른 연봉",size=20)
ax3.set_xlabel("전기기사 자격증 유무",size=12)
ax3.set_ylabel("연봉(만원/년)",size=12)
for i in ax3.containers:
    ax3.bar_label(i,size=12)
ax3.bar_label

plt.show()

# %%
fig= plt.figure(figsize=(20,7))
ax1 = fig.add_subplot(1,3,1)
ax2 = fig.add_subplot(1,3,2)
ax3 = fig.add_subplot(1,3,3)
contrast_colors = sns.color_palette("Dark2")
sns.barplot(x=["리눅스 사용 O","리눅스 사용 X"], y= [df.loc[df["d"],"임금"].mean(),df.loc[~df["d"],"임금"].mean()],palette=contrast_colors,ax=ax1,edgecolor="black")
ax1.set_title("리눅스 언어에 따른 연봉",size=20)
ax1.set_xlabel("리눅스 언어 사용 여부",size=12)
ax1.set_ylabel("연봉(만원/년)",size=12)
for i in ax1.containers:
    ax1.bar_label(i,size=12)
ax1.bar_label

sns.barplot(x=["C 언어 O","C 언어 X"], y= [df.loc[df["e"],"임금"].mean(),df.loc[~df["e"],"임금"].mean()],palette=contrast_colors,ax=ax2,edgecolor="black")
ax2.set_title("C 언어에 따른 연봉",size=20)
ax2.set_xlabel("C 언어 사용 여부",size=12)
ax2.set_ylabel("연봉(만원/년)",size=12)
for i in ax2.containers:
    ax2.bar_label(i,size=12)
ax2.bar_label

sns.barplot(x=["JAVA 언어 O","JAVA 언어 X"], y= [df.loc[df["f"],"임금"].mean(),df.loc[~df["f"],"임금"].mean()],palette=contrast_colors,ax=ax3,edgecolor="black")
ax3.set_title("JAVA 언어에 따른 연봉",size=20)
ax3.set_xlabel("JAVA 언어 사용 여부",size=12)
ax3.set_ylabel("연봉(만원/년)",size=12)
for i in ax3.containers:
    ax3.bar_label(i,size=12)
ax3.bar_label

plt.show()

# %%
fig= plt.figure(figsize=(20,7))
ax1 = fig.add_subplot(1,3,1)
ax2 = fig.add_subplot(1,3,2)
ax3 = fig.add_subplot(1,3,3)
contrast_colors = sns.color_palette("Dark2")
sns.barplot(x=["JAVASCRIPT 언어 O","JAVASCRIPT 언어 X"], y= [df.loc[df["g"],"임금"].mean(),df.loc[~df["g"],"임금"].mean()],palette=contrast_colors,ax=ax1,edgecolor="black")
ax1.set_title("JAVASCRIPT 언어에 따른 연봉",size=20)
ax1.set_xlabel("JAVASCRIPT 언어 사용 여부",size=12)
ax1.set_ylabel("연봉(만원/년)",size=12)
for i in ax1.containers:
    ax1.bar_label(i,size=12)
ax1.bar_label

sns.barplot(x=["HTML 언어 O","HTML 언어 X"], y= [df.loc[df["h"],"임금"].mean(),df.loc[~df["h"],"임금"].mean()],palette=contrast_colors,ax=ax2,edgecolor="black")
ax2.set_title("HTML 언어에 따른 연봉",size=20)
ax2.set_xlabel("HTML 언어 사용 여부",size=12)
ax2.set_ylabel("연봉(만원/년)",size=12)
for i in ax2.containers:
    ax2.bar_label(i,size=12)
ax2.bar_label

sns.barplot(x=["PYTHON 언어 O","PYTHON 언어 X"], y= [df.loc[df["i"],"임금"].mean(),df.loc[~df["i"],"임금"].mean()],palette=contrast_colors,ax=ax3,edgecolor="black")
ax3.set_title("PYTHON 언어에 따른 연봉",size=20)
ax3.set_xlabel("PYTHON 언어 사용 여부",size=12)
ax3.set_ylabel("연봉(만원/년)",size=12)
for i in ax3.containers:
    ax3.bar_label(i,size=12)
ax3.bar_label

plt.show()

# %%
fig= plt.figure(figsize=(10,7))
ax1 = fig.add_subplot(1,1,1)

sns.barplot(x=df["학력"],y=df["임금"],data=df,ax=ax1,edgecolor="black",ci=None)
ax1.set_title("학력별 연봉",size=20)
ax1.set_xlabel("학력",size=12)
ax1.set_ylabel("연봉(만원/년)",size=12)
for i in ax1.containers:
    ax1.bar_label(i,size=12)

plt.show()
# Out:
# C:\Users\KDP-26-\AppData\Local\Temp\ipykernel_11864\1901971376.py:4: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.barplot(x=df["학력"],y=df["임금"],data=df,ax=ax1,edgecolor="black",ci=None)

# %%
fig= plt.figure(figsize=(14,7))
ax1 = fig.add_subplot(1,1,1)

sns.barplot(x=df["지역"],y=df["임금"],data=df,ax=ax1,edgecolor="black",ci=None)
ax1.set_title("지역별 연봉",size=20)
ax1.set_xlabel("지역",size=12)
ax1.set_ylabel("연봉(만원/년)",size=12)
plt.xticks(rotation=45)

for i in ax1.containers:
    ax1.bar_label(i,size=12)

plt.show()
# Out:
# C:\Users\KDP-26-\AppData\Local\Temp\ipykernel_11864\557969012.py:4: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.barplot(x=df["지역"],y=df["임금"],data=df,ax=ax1,edgecolor="black",ci=None)

# %%
fig= plt.figure(figsize=(10,7))
ax1 = fig.add_subplot(1,1,1)

sns.barplot(x=df["고용형태"],y=df["임금"],data=df,ax=ax1,edgecolor="black",ci=None)
ax1.set_title("고용형태에 따른 연봉",size=20)
ax1.set_xlabel("고용형태",size=12)
ax1.set_ylabel("연봉(만원/년)",size=12)
for i in ax1.containers:
    ax1.bar_label(i,size=12)
plt.show()
# Out:
# C:\Users\KDP-26-\AppData\Local\Temp\ipykernel_11864\1953307035.py:4: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.barplot(x=df["고용형태"],y=df["임금"],data=df,ax=ax1,edgecolor="black",ci=None)

# %%
# df["직무내용"].str.replace("\xa0","").str.replace("\r","").to_list()

# %%
fig= plt.figure(figsize=(15,7))
ax1 = fig.add_subplot(1,1,1)

sns.barplot(x="지역",y="임금",hue="학력",data=df,ax=ax1,edgecolor="black",ci=None)
ax1.set_title("학력별 지역별 연봉",size=20)
ax1.set_xlabel("지역",size=12)
ax1.set_ylabel("연봉(만원/년)",size=12)
plt.xticks(rotation=45)

plt.show()
# Out:
# C:\Users\KDP-26-\AppData\Local\Temp\ipykernel_11864\3263999474.py:4: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.barplot(x="지역",y="임금",hue="학력",data=df,ax=ax1,edgecolor="black",ci=None)

# %%
fig= plt.figure(figsize=(10,10))
ax1= fig.add_subplot(1,1,1)

table1= df.pivot_table(index=["지역"],columns=["근무형태"],aggfunc="size")
sns.heatmap(table1,annot=True,cmap="YlOrBr",ax=ax1)
# ax1.set_xticklabels(["월요일","화요일","수요일","목요일","금요일","토요일","일요일"])
ax1.set_xlabel(xlabel="지역",size=12)
ax1.set_ylabel(ylabel="근무형태",size=12)
ax1.set_title("지역별 근무형태",size=20)

plt.show()

# %%
list_work=" ".join(df["직무내용"].str.replace("\xa0","").str.replace("\r","").to_list())

# %%
list_work
# Out:
# '1.업무:서버운영및관리,전산DB데이터관리,네트워크장비관리,VOIP장비관리,보안시스템운영,계열사정보보안관리,MS-SQLDB관리,C#개발2.필수사항:관련학과전공자,운전가능자3.우대사항:장기근속자,동일직무근무자(~5년미만) 직무-ASP,Javascript,JAVA,정보처리기사자격자격요건및우대사항-웹엔지니어경험자전형절차서류전형>면접진행>최종합격근무환경및복지-수습기간:3개월-수습기간중급여지급:100%지급-근무요일:월~금-근무시간:09시~18시-급여일자:25일-상여금/성과급/보너스:연말성과금있음-기타수당/기타처우①선택적복지(기혼자2백만원/미혼자1백만원)/건강,병원,치과등②핸드폰사용료지원③식대및업무상교통비지원-연차수당지급여부:전체사용-퇴직금지급여부:퇴직연금-식사제공:중식제공,업무상필요시조식,석식제공-기숙사제공:미제공-통근차량운행또는교통비지급:업무상교통비지급기타사항-2003년설립되었으며,2020년AI기업으로피보팅된기업으로전체인력중개발자70%이상이며,현재공공기관,금융기관,대기업중심으로개발을해주고있음.-개발자17명중특급인력(15년이상)이5명으로도움받을수있음기업정보기업명:지미션기업형태:중소기업업종:솔루션·SI·CRM·ERP설립일:2020.01.02사원수:33명매출액:39억4천만원홈페이지:http://www.gmission.com주소:서울성동구뚝섬로1길25(성수동1가,서울숲한라에코밸리)607호인사담당자정보연락처:02-2038-8451휴대폰:010-3063-8451e메일:dkyang@gmission.com이메일dkyang@gmission.com지원하시면서류검토후개별연락드림 mes(생산관리시스템)개발자신입사원모집합니다.c#이랑DB는오라클사용합니다.열정있고오래같이일할수있는인재구합니다.*설비인터페이스경험있으신분우대 -사내솔루션(ARGOSAPM)운영및기술지원-PC및모바일단말관리-서버및네트워크인프라관리 ■온라인쇼핑몰운영사무원-택배송장출력/사무보조-주문/결제관리-배송/교환/반품관리-재고/판매정보관리 -사내업무에필요한IT서비스운영및지원-시스템및네트워크모니터링-내부PaaS플랫폼기술지원-직원PC관리[필요기술]리눅스,윈도우 글피에서함께성장해나가실개발자를모십니다.○업무분야-전자회로설계-펌웨어코딩-PCB설계-IoT디바이스개발-산업용컨트롤러개발-계측및제어기기개발○전공:전자/전기/제어계측/메카트로닉스 1.담당업무ㆍ프로젝트별테스트필요사항선정및테스트계획수립ㆍ테스트설계및테스트케이스/체크리스트작성ㆍ품질확인을위한다양한테스트수행ㆍ테스트진행중발견된결함관리ㆍ전달력있는테스트결과작성및보고2.자격요건신입(사원급)컴퓨터/시스템공학과전공자우대 의료기기케이스를제작하는업체입니다.[의료기기연구개발>의료기기기구설계제작]기구설계정보수집하기,디자인컨셉설정하기,기구설계하기,시제품제작하기[의료기기연구개발>의료기기생산기술지원]생산공정설계하기,제품표준화하기,생산공정기술지원하기,생산품질관리지원하기남,여불문,초보자가능. 소프트웨어개발에관심이있는책임감있는분을원합니다.•C#언어이해도가높으신분•DB에대한이해도가높으신분(MSSQL,ORACLE)•성실하신분[산업용전자기기소프트웨어개발>응용소프트웨어개발]UI/UX구현하기,네트워크구현하기,모듈구현하기,소프트웨어통합하기,테스트자동화프로그램개발하기 *주요업무-프라이빗클라우드인프라기획및수행ㆍNutanix,VMware,AWS외-유무선네트워크/보안인프라기획및수행ㆍHPEARUBA,SecuiBLUEMAX,PiolinkPAS외*자격요건ㆍ학력:고졸이상ㆍ경력:신입~3년(사원~주임급)ㆍ군필또는면제*우대사항-유관업무경험자ㆍNutanix,VMware등가상화인프라구축/운영ㆍHPEAruba,Samsung,Cisco등유무선네트워크인프라구축/운영ㆍL4,방화벽구축/운영-유관자격증소지자ㆍNCA,NCP,CCNA,CCNP,ACMA,ACMP등*전형절차ㆍ서류전형>1차면접>임원면접>최종합격ㆍ면접일정은추후통보됩니다.*기타사항ㆍ경력직은직급/연봉협의후확정(이력서에희망연봉및직급명시요망)ㆍ직원개인노트북지급/필요시별도모니터포함ㆍ정규직채용직원전원업무용법인카드지급ㆍ장기근속(5년,10년)휴가및휴가비지급ㆍ중식제공및추가근무에따른식사제공ㆍ자유로운연차사용ㆍ직원간친목활동지원(동호회운영,비정기회식비등)ㆍ유연한출퇴근(근무지외업무시직출/직퇴,대체휴무,회식참석강요없음)*유의사항ㆍ허위사실이발견될경우채용이취소될수있습니다. 저희는축산물을판매하는회사로서축산물관련쇼핑몰을준비중인업체입니다.쇼핑몰운영을성실히해주실분모집합니다.주요업무로는쇼핑몰운영및경리업무입니다.근무시간은09시부터17시까지입니다.한주는월요일부터토요일까지근무이며그다음주는화요일부터금요일까지입니다. 로봇및자동화장치프로그램ROS및PLC프로그램가능자[로봇소프트웨어개발>로봇시스템통합소프트웨어개발]다수로봇제어소프트웨어개발하기,서버연동소프트웨어개발하기,통합모니터링소프트웨어개발하기[로봇소프트웨어개발>경로계획소프트웨어개발]소프트웨어경로계획하기,소프트웨어궤적계획하기,충돌회피경로계획하기 신입직원을채용합니다.일은저희가알려드립니다.공부하고자하는열정과컴퓨터에대한열정이높으면지원가능합니다.의지가중요합니다.1.신입데이타베이스유지보수,관리,장애처리(oracle,mysql등)채용인원:1~2명내외2.신입WAS(webapplicationserver)유지보수관리,장애처리(weblogic,apache,tomcat외)채용인원:1~2명내외 서빙로봇설치,개발,평가,생산및서비스[로봇기구개발>로봇통합및기능시험]로봇통합하기,기능시험하기[로봇기구개발>로봇성능및신뢰성시험]성능시험하기,신뢰성시험하기,필드테스트하기[로봇기구개발>로봇운용]로봇운용하기,로봇시스템운용하기[로봇기구개발>로봇유지보수]로봇유지보수하기,로봇시스템유지보수하기[로봇기구개발>로봇생산관리]로봇생산계획수립및조립,생산전반관리 담당업무-매일새옷제휴점교육및운영관리-앱서비스이슈및개선방안파악-앱이용고객서비스지원-PMS이용업체교육및원격서비스지원(신입도가능,배워서할수있는업무)자격요건-적극적이고커뮤니케이션이원활하신분-중재및설득에능숙하신분-전략적사고를통한문제해결이가능하신분-긍정적인마인드소유자우대사항-해당직무근무경험이있으신분-MSOffice활용이가능하신분-컴퓨터,스마트기기활용이능숙하신분근무조건-고용형태:정규직-급여:면접후결정-근무시간-월~금:09~18시(점심12~13시)-토,일,공휴일휴무-근무지역:(07261)서울영등포구양산로91리드원센터-인근전철:서울5호선영등포구청역에서300m이내복리후생-매월매일새옷세탁포인트50,000포인트지원-해외리프레쉬휴가경비지원(1년이상근무한임직원대상)-최고급사양장비지원-생일휴가1일-도서지원제도-경조사비지급-명절선물-끊이지않는간식 2023년도클라우드창업성장지원(K-ICT클라우드혁신센터운영) 프로그램개발-병원정보시스템프로그램개발,유지관리 #고객관련된솔루션설치지원및설치한제품유지관리지원.1.백업솔루션:베리타스(VeritasNetBackup)2.백업테이프저장장치:스펙트라로직3.서버이중화솔루션:베리타스(VeritasInfoscale)4.아카이브솔루션:스펙트라로직(Storcycle)*열심히하고자하는의지만있으시면교육및업무에잘적응할수있도록지원해드립니다.***저희는개발자를뽑지않습니다.지원하지마세요. [담당업무]1.웹프로그램개발프론트/백엔드사용기술-java-jsp-vuejs업무내용웹프로그램개발및유지보수 홈페이지,블로그,SNS광고업데이트,포토샵,어도비일러스트작업온라인마케팅업무겸업및영업지원 MicrochipPIC계열임베디드프로그램개발자CortexM계열임베디드프로그램개발자로봇제어부프로그램개발드론펌웨어개발 순천만국제정원박람회내에서스카이큐브를운영하는회사입니다.(주)우진피알티기술본부채용공통자격요건ㆍ학력:무관담당업무ㆍ기술본부:PRT설비운영,차량운행제어,무인운행시스템,자동화설비우대사항ㆍIT실무경험자,OA및리눅스활용자,자동화시스템,철도학과,전자공학,기계공학,컴퓨터관련학과이공계열지원자격ㆍ경력:무관(신입도지원가능)임금ㆍ회사내규에따름 주요업무-인공지능알고리즘개발및연구-인공지능서비스솔루션개발-Vision/TimeSeries데이터처리및분석자격요건-전반적인AI기술에대한이해가있으신분-Vision/TimeSeries딥러닝모델에대한이해및학습경험-딥러닝프레임워크(Pytorch,Tensorflow등)사용-데이터를분석하거나모델링을통해결과를도출해낸경험이있으신분*서류전형합격자에한하여면접일정별도안내드립니다. 회사(생산제조업체)및대학에서이루어지는업무를Javascript,Jquery를사용하여웹프로그램개발을수행합니다(프런트엔드개발) 직무내용-전기차충전기U ...

# %%
import numpy as np
import PIL


icon = PIL.Image.open(r'C:\Users\KDP-26-\Desktop\Web_Crawling\project\electronic.png')
img = PIL.Image.new('RGB', icon.size, (255,255,255))
img.paste(icon, icon)
img = np.array(img)



from wordcloud import WordCloud
from konlpy.tag import Okt
from collections import	Counter
import platform
okt = Okt()	# Open Korean Text 객체 생성
# okt함수를 통해 읽어들인 내용의 형태소 분석
sentences_tag =	[]
sentences_tag =	okt.pos(list_work)

noun_adj_list =	[]
# tag가 명사이거나 형용사인 단어들만 noun_adj_list에 넣어준다.
for	word, tag in sentences_tag:
    if tag in ['Noun' , 'Adjective']:
        noun_adj_list.append(word)
print(noun_adj_list)

# 가장 많이 나온 단어부터 40개를 저장한다.
counts = Counter(noun_adj_list)
tags = counts.most_common(40)
tags.pop(0)

# 폰트
if platform.system() == 'Windows':
    path = r'C:\Users\KDP-26-\AppData\Local\Microsoft\Windows\Fonts\TENADA.ttf'
wc = WordCloud(font_path=path, background_color="white", max_font_size=150,mask=img, colormap='inferno', random_state=12)
cloud = wc.generate_from_frequencies(dict(tags))

plt.figure(figsize=(20,	10))
plt.axis('off')
plt.imshow(cloud)
plt.show()
# Out:
# ['업무', '서버', '운영', '및', '관리', '전산', '데이터', '관리', '네트워크', '장비', '관리', '장비', '관리', '보안', '시스템', '운영', '계열', '정보보안', '관리', '관리', '개발', '필수', '사항', '관련', '학과', '전공자', '운전', '가능', '우대', '사항', '장기', '근속', '직무', '근무', '직무', '정보처리기사', '자격', '자격', '요건', '및', '우대', '사항', '웹', '엔지니어', '경험', '자전', '절차', '서류', '전형', '면접', '진행', '최종', '합격', '근무', '환경', '및', '복지', '수습', '기간', '개월', '수습', '기간', '급여', '지급', '지급', '근무', '요일', '월', '금', '근무시간', '급여', '일자', '상여금', '성과급', '보너스', '연말', '과금', '있음', '기타', '수당', '기타', '처우', '선택', '복지', '혼자', '백만원', '미혼', '백만원', '건강', '병원', '치과', '등', '핸드폰', '사용', '료', '지원', '식대', '및', '업무', '교통비', '지원', '연차', '수당', '지급', '여부', '전체', '사용', '퇴직금', '지급', '여부', '퇴직', '연금', '식사', '제공', '중식', '제공', '업무', '필요시', '조식', '석식', '제공', '기숙사', '제공', '미제', '공', '통근', '차량', '운행', '교통비', '지급', '업무', '교통비', '지급', '기타', '사항', '기업', '피보팅', '기업', '전체', '인력', '개발자', '이상', '현재', '공공기관', '금융기관', '대기업', '중심', '개발', '개발자', '명중', '특급', '인력', '이', '명', '도움', '기업', '정보', '기업', '미션', '기업', '형태', '중소기업', '업종', '솔루션', '설립', '일', '사원수', '명', '매출', '액', '주소', '서울', '성동구', '뚝섬', '로', '길', '성수동', '서울숲', '한라', '에코', '밸리', '호인', '담당자', '정보', '연락처', '휴대폰', '메일', '이메일', '지원', '서류', '검토', '후', '개별', '연락', '드림', '생산', '관리', '시스템', '개발자', '신입사원', '모집', '오라클', '사용', '열정', '있고오래', '같', '이일', '인재', '구합', '설비', '인터페이스', '경험', '있으', '신분', '우대', '사내', '솔루션', '운영', '및', '기술', '지원', '및', '모바일', '단말', '관리', '서버', '및', '네트워크', '인프라', '관리', '온라인', '쇼핑몰', '운영', '사무', '택배', '송장', '출력', '사무', '보조', '주문', '결제', '관리', '배송', '교환', '반품', '관리', '재고', '판매', '정보', '관리', '업무', '필요한', '서비스', '운영', '및', '지원', '시스템', '및', '네트워크', '모니터링', '내부', '플랫폼', '기술', '지원', '직원', '관리', '필요', '기술', '리눅스', '윈도우', '글피', '성장해', '개발자', '업무', '분야', '전자회로', '설계', '펌웨어', '코딩', '설계', '디바이스', '개발', '산업', '용', '컨트롤러', '개발', '계', '및', '제어', '기기', '개발', '전공', '전자', '전기', '제어', '계', '메카트로닉스', '담당', '업무', '프로젝트', '테스트', '필요', '사항', '선정', '및', '테스트', '계획', '수립', '테스트', '설계', '및', '테스트', '케이스', '체크', '리스트', '작성', '품질', '확인', '위', '다양한', '테스트', '수행', '테스트', '진행중', '발견', '결함', '관리', '전달', '있는', '테스트', '결과', '작성', '및', '보고', '자격', '요건', '신입', '사원', '컴퓨터', '시스템', '학과', '전공자', '우대', '의료기기', '케이스', '제작', '업체', '입니다', '의료기기', '연구개발', '의료기기', '기구설계', '제작', '기구설계', '정보', '수집', '디자인', '컨셉', '설정', '기구설계', '제품', '제작', '의료기기', '연구개발', '의료기기', '생산', '기술', '지원', '생산', '정설', '제품', '표준', '화하기', '생산', '공정', '기술', '원하기', '생산', '품질', '관리', '원하기', '남', '불문', '초보자', '가능', '소프트웨어', '개발', '관심', '있는', '책임감', '있는', '분', '원합니다', '언어', '이해도', '높으', '신분', '이해도', '높으', '신분', '성실하', '신분', '산업', '용', '전자기기', '소프트웨어', '개발', '응용소프트웨어', '개발', '구현', '네트워크', '구현', '모듈', '구현', '소프트웨어', '통합', '테스트', '자동화', '프로그램', '개발', '업무', '프라이', '빗', '클라우드', '인프라', '기획', '및', '수행', '외', '유', '무선', '네트워크', '보안', '인프라', '기획', '및', '수행', '외', '자격', '요건', '학력', '졸', '이상', '경력', '신입', '사원', '주임', '군필', '면제', '우대', '사항', '유관', '업무', '경험', '등', '가상화', '인프라', '구축', '운영', '등유', '무선', '네트워크', '인프라', '구축', '운영', '방화벽', '구축', '운영', '유관', '자격증', '소지', '등', '전형', '절차', '서류', '전형', '차', '면접', '임원', '면접', '최종', '합격', '면접', '일정', '추후', '통보', '기타', '사항', '경력', '직', '직급', '연봉', '협의', '후', '확정', '이력서', '희망', '연봉', '및', '직급', '요망', '직원', '개인', '노트북', '지급', '필요시', '별도', '모니터', '포함', '정규직', '채용', '직원', '업무', '용법', '카드', '지급', '장기', '근속', '휴가', '및', '휴가', '비지', '중식', '및', '추가', '근무', '식사', '제공', '자유로운', '연차', '사용', '직원', '친목', '활동', '지원', '동호회', '운영', '비정', '기회', '비등', '유연한', '출퇴근', '근무', '외', '업무', '직출', '직퇴', '대체', '휴무', '회식', '참석', '강요', '없음', '유의사항', '허위', '사실', '발견', '경우', '채용', '취소', '저희', '축산물', '판매', '회사', '로서', '축산물', '관련', '쇼핑몰', '준비', '업체', '입니다', '쇼핑몰', '운영', '성실히', '분모', '집합', '업무', '쇼핑몰', '운영', '및', '경리', '업무', '입니다', '근무시간', '한주', '월요일', '토요일', '근무', '다음주', '화요일', '금요일', '입니다', '로봇', '및', '자동화', '장치', '프로그램', '및', '프로그램', '가능', '로봇', '소프트웨어', '개발', '로봇', '시스템', '통합', '소프트웨어', '개발', '다수', '로봇', '제어', '소프트웨어', '개발', '서버', '소프트웨어', '개발', '통합', '모니터링', '소프트웨어', '개발', '로봇', '소프트웨어', '개발', '경로', '계획', '소프트웨어', '개발', '소프트웨어', '경로', '계획', '소프트웨어', '궤', '계획', '충돌', '회피', '경로', '계획' ...

# %%
list_work2=" ".join(df["모집직종"].str.replace("\xa0","").str.replace("\r","").to_list())

icon = PIL.Image.open(r'C:\Users\KDP-26-\Desktop\Web_Crawling\project\electronic.png')
img2 = PIL.Image.new('RGB', icon.size, (255,255,255))
img2.paste(icon, icon)
img = np.array(img2)

okt =	Okt()	#	Open	Korean	Text	객체 생성
#	okt함수를 통해 읽어들인 내용의 형태소를 분석한다.
sentences_tag =	[]
sentences_tag =	okt.pos(list_work2)

noun_adj_list =	[]
#	tag가 명사이거나 형용사인 단어들만 noun_adj_list에 넣어준다.
for	word,	tag	in	sentences_tag:
    if	tag	in	['Noun'	,	'Adjective']:
        noun_adj_list.append(word)
print(noun_adj_list)
#	가장 많이 나온 단어부터 40개를 저장한다.
counts	=	Counter(noun_adj_list)
tags	=	counts.most_common(40)
tags.pop(0)

if	platform.system()	==	'Windows':
    path	=	r'C:\Users\KDP-26-\AppData\Local\Microsoft\Windows\Fonts\TENADA.ttf'
wc =	WordCloud(font_path=path,	background_color="white",	max_font_size=200,mask=img, colormap='inferno')
cloud	=	wc.generate_from_frequencies(dict(tags))

plt.figure(figsize=(20,	10))
plt.axis('off')
plt.imshow(cloud)
plt.show()
# Out:
# ['정보', '시스템', '운영자', '웹개발자', '웹', '엔지니어', '웹', '프로그래머', '언어', '및', '외', '프로그래밍언어', '전문가', '기술', '지원', '전문가', '웹', '운영자', '홈페이지', '관리자', '기술', '지원', '전문가', '자제', '계', '기술자', '및', '연구원', '테스', '터및', '전문가', '데이터', '설계', '및', '프로그래머', '응용소프트웨어', '개발자', '기술', '지원', '전문가', '웹', '운영자', '홈페이지', '관리자', '로봇공학', '기술자', '및', '연구원', '기술', '지원', '전문가', '로봇공학', '기술자', '및', '연구원', '고객', '상담', '고장', '제품', '사용', '시스템소프트웨어', '개발자', '시스템소프트웨어', '개발자', '기술', '지원', '전문가', '웹개발자', '웹', '엔지니어', '웹', '프로그래머', '웹', '운영자', '홈페이지', '관리자', '펌웨어', '및', '임베디드', '소프트웨어', '프로그래머', '관', '제사', '항공', '선박', '철도', '등', '데이터', '분석', '빅데이터', '분석', '웹개발자', '시스템소프트웨어', '개발자', '웹', '기획', '응용소프트웨어', '개발자', '테스', '터및', '전문가', '웹', '기획', '응용소프트웨어', '개발자', '응용소프트웨어', '개발자', '시스템소프트웨어', '개발자', '웹개발자', '웹', '엔지니어', '웹', '프로그래머', '기술', '지원', '전문가', '데이터', '전문가', '웹개발자', '시스템소프트웨어', '개발자', '프로그래머', '기술', '지원', '전문가', '웹', '디자이너', '웹', '운영자', '홈페이지', '관리자', '컴퓨터', '시스템', '설계', '및', '분석', '펌웨어', '및', '임베디드', '소프트웨어', '프로그래머', '응용소프트웨어', '개발자', '테스', '터및', '전문가', '시스템소프트웨어', '개발자', '테스', '터및', '전문가', '기술', '지원', '전문가', '시스템소프트웨어', '개발자', '프로그래머', '응용소프트웨어', '개발자', '데이터', '설계', '및', '프로그래머', '네트워크', '관리자', '우딩', '컴퓨터', '운영', '관리자', '응용소프트웨어', '개발자', '기술', '지원', '전문가', '네트워크', '관리자', '우딩', '컴퓨터', '운영', '관리자', '웹개발자', '웹', '엔지니어', '웹', '프로그래머', '언어', '및', '외', '프로그래밍언어', '전문가', '기계', '제어', '기술자', '전기', '패널', '계장', '정자동', '등', '기계', '제어', '기술자', '전기', '패널', '계장', '정자동', '등', '데이터', '설계', '및', '프로그래머', '언어', '및', '외', '프로그래밍언어', '전문가', '웹개발자', '웹', '엔지니어', '웹', '프로그래머', '기술', '지원', '전문가', '응용소프트웨어', '개발자', '웹개발자', '응용소프트웨어', '개발자', '웹개발자', '웹개발자', '응용소프트웨어', '개발자', '기술', '지원', '전문가', '프로그래밍언어', '전문가', '응용소프트웨어', '개발자', '웹개발자', '웹', '엔지니어', '웹', '프로그래머', '웹개발자', '웹', '엔지니어', '웹', '프로그래머', '범용', '응용소프트웨어', '프로그래머', '정보처리', '재무관리', '등', '정보', '시스템', '운영자', '정보', '시스템', '운영자', '응용소프트웨어', '개발자', '기술', '지원', '전문가', '웹개발자', '웹', '엔지니어', '웹', '프로그래머', '기술', '지원', '전문가', '시스템소프트웨어', '개발자', '정보통', '설치', '수리', '웹개발자', '웹', '엔지니어', '웹', '프로그래머', '응용소프트웨어', '개발자', '기술', '지원', '전문가', '테스', '터및', '전문가', '기술', '지원', '전문가', '기술', '지원', '전문가', '응용소프트웨어', '개발자', '웹개발자', '웹', '엔지니어', '웹', '프로그래머', '시스템소프트웨어', '개발자', '기술', '지원', '전문가', '웹개발자', '웹', '엔지니어', '웹', '프로그래머', '언어', '및', '외', '프로그래밍언어', '전문가', '범용', '응용소프트웨어', '프로그래머', '정보처리', '재무관리', '등', '펌웨어', '및', '임베디드', '소프트웨어', '프로그래머']
