# %%
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.common.by import By
import time

# %%
name = '영화 ' + '범죄도시3'

# %%
# 크롬창 열기
driver=webdriver.Chrome()

# %%
driver.get('https://www.naver.com')
driver.implicitly_wait(10) # 정보가 모두 뜰 때까지 최대 10초를 기다린다
time.sleep(3)

search=driver.find_element(By.ID, 'query') # id가 query인 항목 찾기
search.send_keys(name)
time.sleep(1)

search.send_keys(Keys.RETURN) # => enter 키

# %%
def search_naver(name):
    name = '영화 ' + name
    
    driver=webdriver.Chrome()
    driver.get('https://www.naver.com')
    driver.implicitly_wait(10) 
    time.sleep(3)

    search=driver.find_element(By.ID, 'query')
    search.send_keys(name)
    time.sleep(1)

    search.send_keys(Keys.RETURN)

# %%
name = '인사이드아웃'
search_naver(name)

# %% [markdown]
# # 등급

# %%
import pandas as pd 
import os

# %%
grade = pd.read_csv('./movie_grade_.csv', encoding='utf-8')
grade
# Out:
#       구분      종별              한글제명                                 원제명  \
# 0   국내영화     극영화             택시운전사                               택시운전사
# 1   국외영화   애니메이션       하늘에서음식이내린다면   CLOUDY WITH A CHANCE OF MEATBALLS
# 2   국외영화     극영화   범죄도시: 나쁜놈들 전성시대                       Eminence Hill
# 3   국내영화     극영화             범죄도시2                               범죄도시2
# 4   국내영화     극영화             범죄도시3                               범죄도시3
# 5   국외영화     극영화                그녀                                 her
# 6   국외영화   애니메이션       토이 스토리 4 3D                         TOY STORY 4
# 7   국외영화   애니메이션          토이 스토리 4                         TOY STORY 4
# 8   국외영화   애니메이션         다락방의토이스토리                   Toys in the Attic
# 9   국외영화   애니메이션            토이스토리3                         TOY STORY 3
# 10  국외영화     극영화            토이스토리2                         TOY STORY 2
# 11  국외영화   애니메이션             토이스토리                           TOY STORY
# ...

# %%
grade.columns
# Out:
# Index(['구분', ' 종별', ' 한글제명', ' 원제명', ' 상영시간', ' 관람등급', ' 신청사', ' 신청사대표',
#        ' 등급분류일자', ' 등급분류(추천)번호', ' 제작국(신청사)', ' 주제', ' 선정성', ' 폭력성', ' 대사',
#        ' 공포', ' 약물', ' 모방위험'],
#       dtype='object')

# %%
grade = grade[[' 한글제명',' 관람등급']]
grade.columns = ['제목', '관람등급']
grade['관람등급'].replace('연소자관람가','12세이상관람가',inplace=True)
grade
# Out:
# C:\Users\KDP-26-\AppData\Local\Temp\ipykernel_19836\1376172704.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   grade['관람등급'].replace('연소자관람가','12세이상관람가',inplace=True)
#                   제목       관람등급
# 0              택시운전사   15세이상관람가
# 1        하늘에서음식이내린다면      전체관람가
# 2    범죄도시: 나쁜놈들 전성시대    청소년관람불가
# 3              범죄도시2   15세이상관람가
# 4              범죄도시3   15세이상관람가
# 5                 그녀    청소년관람불가
# 6        토이 스토리 4 3D      전체관람가
# 7           토이 스토리 4      전체관람가
# 8          다락방의토이스토리      전체관람가
# 9             토이스토리3      전체관람가
# 10            토이스토리2      전체관람가
# 11             토이스토리     연소자관람가
# 12               미나리   12세이상관람가
# 13              극한직업   15세이상관람가
# 14       인사이드 아웃(3D)      전체관람가
# 15           인사이드 아웃      전체관람가
# 16               전우치   12세이상관람가
